# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# Price Recommendation for Used Car
#
# Marketing Requirement: 80% of predictions fall between -15% and +15% of actual price

# %% [markdown]
# ### Initial Setups

# %%
#Required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
#Read data from csv file
data = pd.read_csv('Data\cs_03.csv')
data.head()
# Out:
#    no       time    city                   brand  production_year    color
# 0   1  3/26/2022  Tehran     PEUGEOT 405 GLX GAS             1393  نقره ای  \
# 1   2   3/5/2022  Tehran       PEUGEOT 206 SD V8             1393     سفید
# 2   3  3/26/2022  Tehran      PEUGEOT 206 Type 2             1397     سفید
# 3   4  3/19/2022  Tehran  PEUGEOT 207i AUTOMATIC             1390     سفید
# 4   5  3/19/2022  Tehran     PEUGEOT 207i MANUAL             1396     سفید
#
#        km     body_condition engine_condition chassis_condition
# 0   80000  سالم و بی خط و خش             سالم       سالم و پلمپ  \
# 1   85000       خط و خش جزیی             سالم       سالم و پلمپ
# 2   46000       خط و خش جزیی             سالم       سالم و پلمپ
# 3  165000  سالم و بی خط و خش             سالم       سالم و پلمپ
# 4   50000  سالم و بی خط و خش             سالم       سالم و پلمپ
#
#    insurance_time_to_expire   gearbox fuel_type      price
# 0                         9   دنده ای  gasoline  187000000
# 1                         4   دنده ای  gasoline  215000000
# 2                        12   دنده ای  gasoline  220000000
# 3                         5  اتوماتیک  gasoline  275000000
# 4                         7   دنده ای  gasoline  310000000

# %%
data.shape
# Out:
# (9512, 14)

# %% [markdown]
# ## Data Understanding - Phase 1

# %% [markdown]
# #### 1: Understand data collection process

# %% [markdown]
# Data crawled from Divar website in March 2022
#
# Note: data collection process is based on user input

# %% [markdown]
# #### 2: Document data set description (meta data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9512 entries, 0 to 9511
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   no                        9512 non-null   int64
#  1   time                      9512 non-null   object
#  2   city                      9512 non-null   object
#  3   brand                     9512 non-null   object
#  4   production_year           9512 non-null   int64
#  5   color                     9512 non-null   object
#  6   km                        9512 non-null   int64
#  7   body_condition            9512 non-null   object
#  8   engine_condition          9512 non-null   object
#  9   chassis_condition         9512 non-null   object
#  10  insurance_time_to_expire  9512 non-null   int64
#  11  gearbox                   9512 non-null   object
#  12  fuel_type                 9512 non-null   object
#  13  price                     9512 non-null   int64
# dtypes: int64(5), object(9)
# memory usage: 1.0+ MB

# %% [markdown]
# 0   no: number
#
# 1   time: registration date on Divar website (date)
#
# 2   city: city of residence (nominal)
#
# 3   brand: car brand name (nominal)
#
# 4   production_year: the year in which the auto was first manufactured (ordinal)
#
# 5   color: color (nominal)
#
# 6   km: kilometerage (numeric)
#
# 7   body_condition: body condition (ordinal)
#
# 8   engine_condition: engine condition (ordinal)
#
# 9   chassis_condition: chasis condition (ordinal)
#
# 10  insurance_time_to_expire: third party insurance time to expire (numeric)
#
# 11  gearbox: if aoutomatic or not (binary)
#
# 12  fuel_type: fuel type (nominal: "gasoline", "CNG", "LPG", "hybrid")
#
# 13  price: sales price in Toman (numeric)

# %% [markdown]
# #### 3: Check for missing values

# %%
np.sum(data.isnull())
# Out:
# no                          0
# time                        0
# city                        0
# brand                       0
# production_year             0
# color                       0
# km                          0
# body_condition              0
# engine_condition            0
# chassis_condition           0
# insurance_time_to_expire    0
# gearbox                     0
# fuel_type                   0
# price                       0
# dtype: int64

# %% [markdown]
# #### 4: Univariate data analysis

# %%
data['no'].nunique()
# Out:
# 9512

# %%
#Check if there is duplicate rows
np.sum(data.duplicated())
# Out:
# 0

# %%
#Convert coulumn 'time' to datetime
data['time'] = pd.to_datetime(data['time'], format = '%m/%d/%Y')

# %%
data['time'].min()
# Out:
# Timestamp('2021-11-27 00:00:00')

# %%
data['time'].max()
# Out:
# Timestamp('2022-04-02 00:00:00')

# %%
data['time'].value_counts()
# Out:
# time
# 2022-03-12    2786
# 2022-03-05    1721
# 2022-03-19    1700
# 2022-03-26    1327
# 2022-04-02     421
# 2022-03-29     407
# 2022-03-30     388
# 2022-03-28     351
# 2022-03-27     340
# 2022-03-10       8
# 2022-02-05       6
# 2022-04-01       6
# 2022-02-12       6
# 2022-02-26       4
# 2022-03-25       4
# 2022-03-13       4
# 2022-02-19       4
# 2022-03-21       3
# 2022-03-31       3
# 2022-03-22       3
# 2022-03-23       2
# 2022-03-24       2
# 2022-03-11       2
# 2022-03-20       2
# 2022-03-17       2
# 2022-01-15       1
# 2022-03-18       1
# 2021-11-27       1
# 2022-01-22       1
# 2022-03-16       1
# 2022-01-29       1
# 2022-03-09       1
# 2022-03-14       1
# 2021-12-11       1
# 2022-03-15       1
# Name: count, dtype: int64

# %%
#Assumption: no data drift
#data drift : occurs when the distribution of the input data changes over time.
#such as inflation in price

# %%
#Histogram of numeric variables
var_ind = [6, 10, 13]
plt.figure(figsize = (9, 3))
plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
for i in range(1, 4):
    plt.subplot(1, 3, i)
    plt.hist(x = data.iloc[: , var_ind[i - 1]], alpha = .4, color = 'red')
    plt.axvline(data.iloc[: , var_ind[i - 1]].mean(), color = 'gray', linewidth = 2, linestyle = '--')

    plt.title(data.columns[var_ind[i - 1]])

# %%
#Summary statistics of numeric variables
data[['km', 'insurance_time_to_expire', 'price']].describe()
# Out:
#                   km  insurance_time_to_expire         price
# count    9512.000000               9512.000000  9.512000e+03
# mean   120604.719407                  7.656644  2.143317e+08
# std    113361.709352                  3.351309  1.149665e+08
# min         0.000000                  1.000000  1.000000e+07
# 25%     25000.000000                  5.000000  1.450000e+08
# 50%     92000.000000                  8.000000  2.150000e+08
# 75%    190000.000000                 11.000000  2.670000e+08
# max    500000.000000                 12.000000  3.000000e+09

# %%
#Frequency table for city
data['city'].value_counts()
# Out:
# city
# Tehran     5038
# Mashhad    1654
# Isfahan    1528
# Shiraz     1292
# Name: count, dtype: int64

# %%
#Frequency table for brnad
data['brand'].value_counts()
# Out:
# brand
# PEUGEOT 405 GLX GAS                1198
# PEUGEOT 206 Type 2                 1171
# PEUGEOT 405 GLX CNG                 898
# PEUGEOT 206 Type 5                  857
# PEUGEOT 206 SD V8                   687
# PEUGEOT PARS SAL                    603
# PEUGEOT 405 SLX GAS                 488
# PEUGEOT PARS LX TU5                 428
# PEUGEOT PARS HYBRID                 350
# PEUGEOT 207i AUTOMATIC              312
# PEUGEOT 207i MANUAL                 308
# PEUGEOT PARS SADE                   266
# PEUGEOT 207i PANAROMA MANUAL        192
# PEUGEOT ROA HYBRID                  182
# PEUGEOT RD GAS                      143
# PEUGEOT RD CNG                      132
# PEUGEOT 405 GL CNG                   93
# PEUGEOT 405 GL GAS                   85
# PEUGEOT PARS AUTOMATIC TU5           85
# PEUGEOT 405 GLX LPG                  77
# PEUGEOT RD LPG                       75
# PEUGEOT PARS ELX                     70
# PEUGEOT 405 GLX TU5 GAS              68
# PEUGEOT 206 Type 3                   58
# PEUGEOT ROA GAS                      54
# PEUGEOT 207i PANAROMA AUTOMATIC      49
# PEUGEOT RDI GAS                      48
# PEUGEOT 405 GLi CNG                  48
# PEUGEOT ROA SAL HYBRID               47
# PEUGEOT 2008                         43
# PEUGEOT 206 SD V20                   41
# PEUGEOT 405 GLi GAS                  37
# PEUGEOT 405 SLX HYBRID               34
# PEUGEOT 206 Type 6                   34
# PEUGEOT 207i SD AUTOMATIC            27
# PEUGEOT 206 SD V1                    26
# PEUGEOT 206 SD V9                    24
# PEUGEOT 405 GL PLG                   21
# PEUGEOT 407                          20
# PEUGEOT 405 GLX TU5 HYBRID           20
# PEUGEOT 206 Type 1                   18
# PEUGEOT PARS ELX XUM                 17
# PEUGEOT 405 GLi LPG                  15
# PEUGEOT 206 SD V2                    12
# PEUGEOT 405 STATION WAGON            11
# PEUGEOT ROA SAL GAS                   6
# PEUGEOT 206 SD V6                     6
# PEUGEOT 206 Type 4                    5
# PEUGEOT 508 GT                        4
# PEUGEOT 404                           4
# PEUGEOT 206 SD V10                    4
# PEUGEOT 504                           3
# PEUGEOT 205                           2
# PEUGEOT 301                           2
# PEUGEOT PARS LIMOUSINE                2
# PEUGEOT 206 SD V19                    1
# PEUGEOT 406                           1
# Name: count, dtype: int64

# %%
data['brand'].nunique()
#Note: too many levels
# Out:
# 57

# %%
#Frequency table for production_year
data['production_year'].value_counts()
#Note: Shamsy year vs. Christian year
# Out:
# production_year
# 1400    1033
# 1398     946
# 1399     934
# 1396     897
# 1397     815
# 1395     647
# 1394     556
# 1393     427
# 1390     384
# 1389     364
# 1388     271
# 1383     260
# 1385     253
# 1392     244
# 1387     243
# 1391     233
# 1384     222
# 1386     203
# 1382     162
# 1381     120
# 1380     109
# 1379      57
# 1378      38
# 2009      19
# 1377      18
# 1376      15
# 1372      12
# 1375       5
# 1374       4
# 2017       3
# 1373       3
# 2016       3
# 2008       2
# 2019       1
# 2002       1
# 1997       1
# 2005       1
# 1370       1
# 2018       1
# 1998       1
# 2000       1
# 2004       1
# 2003       1
# Name: count, dtype: int64

# %%
#Frequency table for color
data['color'].value_counts()
# Out:
# color
# سفید          4334
# نقره ای       1309
# خاکستری       1136
# مشکی           565
# نوک مدادی      493
# یشمی           328
# سفید صدفی      256
# دلفینی         246
# زرد            181
# بژ             101
# سبز             97
# نقرآبی          68
# آبی             63
# عنابی           44
# طوسی            38
# عدسی            36
# قرمز            34
# بادمجانی        32
# آلبالویی        30
# سرمه ای         27
# گیلاسی          20
# ذغالی           15
# اطلسی           10
# بنفش             8
# زیتونی           8
# تیتانیوم         6
# قهوه ای          5
# سربی             5
# زرشکی            4
# نارنجی           3
# مسی              2
# طلایی            2
# کربن بلک         2
# برنز             2
# پوست پیازی       1
# خاکی             1
# Name: count, dtype: int64

# %%
data['color'].nunique()
#Note: too many levels
# Out:
# 36

# %%
#Frequency table for body_condition
data['body_condition'].value_counts()
#Note: too many levels
# Out:
# body_condition
# سالم و بی خط و خش              5220
# خط و خش جزیی                   2005
# رنگ شدگی در ۱ ناحیه             630
# دوررنگ                          604
# رنگ شدگی در ۲ ناحیه             493
# تمام رنگ                        198
# رنگ شدگی در ۳ ناحیه             138
# صافکاری بی رنگ، در ۱ ناحیه      118
# رنگ شدگی در ۴ ناحیه              41
# صافکاری بی رنگ، در ۲ ناحیه       28
# رنگ شدگی در ۵ ناحیه              13
# صافکاری بی رنگ، در ۳ ناحیه        7
# صافکاری بی رنگ، در ۴ ناحیه        6
# صافکاری بی رنگ، در ۱۰ ناحیه       3
# رنگ شدگی در ۶ ناحیه               3
# اوراقی                            2
# رنگ شدگی در ۸ ناحیه               1
# صافکاری بی رنگ، در ۵ ناحیه        1
# رنگ شدگی در ۷ ناحیه               1
# Name: count, dtype: int64

# %%
#Frequency table for engine_condition
data['engine_condition'].value_counts()
# Out:
# engine_condition
# سالم             9405
# نیاز به تعمیر      65
# تعویض شده          42
# Name: count, dtype: int64

# %%
#Frequency table for chassis_condition
data['chassis_condition'].value_counts()
# Out:
# chassis_condition
# سالم و پلمپ    9381
# ضربه خورده      116
# رنگ شده          15
# Name: count, dtype: int64

# %%
#Frequency table for gearbox
data['gearbox'].value_counts()
# Out:
# gearbox
# دنده ای     8897
# اتوماتیک     615
# Name: count, dtype: int64

# %%
#Frequency table for fuel_type
data['fuel_type'].value_counts()
# Out:
# fuel_type
# gasoline    7541
# CNG         1171
# hybrid       633
# LPG          167
# Name: count, dtype: int64

# %% [markdown]
# ## Data Preparation

# %%
#Extract the model from brand name
data['model'] = data['brand'].apply(lambda s: s.split()[1])
data['model'].value_counts()
# Out:
# model
# 405     3093
# 206     2944
# PARS    1821
# 207i     888
# RD       350
# ROA      289
# RDI       48
# 2008      43
# 407       20
# 404        4
# 508        4
# 504        3
# 301        2
# 205        2
# 406        1
# Name: count, dtype: int64

# %%
#Reduce the number of levels in brand
data.loc[data['model'].isin(['404', '508', '504', '301', '205', '406']), 'model'] = 'other'
data['model'].value_counts()
# Out:
# model
# 405      3093
# 206      2944
# PARS     1821
# 207i      888
# RD        350
# ROA       289
# RDI        48
# 2008       43
# 407        20
# other      16
# Name: count, dtype: int64

# %%
data.loc[data['model'] == 'other', :]
#Note: PEUGEOT 404 production years are suspecious!
# Out:
#         no       time     city           brand  production_year      color
# 936    937 2022-03-29   Tehran     PEUGEOT 404             2005         بژ  \
# 1422  1423 2022-03-12   Tehran     PEUGEOT 301             2016       سفید
# 1775  1776 2022-03-05   Tehran     PEUGEOT 406             2019       سفید
# 2259  2260 2022-03-19   Tehran     PEUGEOT 404             2002       مشکی
# 2515  2516 2022-03-26   Tehran     PEUGEOT 301             2016       سفید
# 2905  2906 2022-04-02   Tehran     PEUGEOT 205             1997       طوسی
# 2993  2994 2022-03-05   Tehran  PEUGEOT 508 GT             2017  سفید صدفی
# 3817  3818 2022-03-05   Tehran     PEUGEOT 404             2018  نوک مدادی
# 4800  4801 2022-03-26   Tehran  PEUGEOT 508 GT             2017  سفید صدفی
# 5913  5914 2022-03-27  Mashhad  PEUGEOT 508 GT             2016  سفید صدفی
# 6098  6099 2022-03-19  Mashhad  PEUGEOT 508 GT             2017    نقره ای
# 7455  7456 2022-03-12  Isfahan     PEUGEOT 404             2008    نقره ای
# 7921  7922 2022-03-12  Isfahan     PEUGEOT 205             1998         بژ
# 8183  8184 2022-03-05  Isfahan     PEUGEOT 504             2000      عنابی
# 8195  8196 2022-03-12  Isfahan     PEUGEOT 504             2004        سبز
# 9276  9277 2022-03-12   Shiraz     PEUGEOT 504             2003       مشکی
#
#           km       body_condition engine_condition chassis_condition
# 936   111111         خط و خش جزیی             سالم       سالم و پلمپ  \
# 1422   45000    سالم و بی خط و خش             سالم       سالم و پلمپ
# 1775   32000    سالم و بی خط و خش             سالم       سالم و پلمپ
# 2259  400000         خط و خش جزیی             سالم       سالم و پلمپ
# 2515   70000    سالم و بی خط و خش             سالم       سالم و پلمپ
# 2905     250               دوررنگ             سالم       سالم و پلمپ
# 2993    4000    سالم و بی خط و خش             سالم       سالم و پلمپ
# 3817   89000  رنگ شدگی در ۲ ناحیه             سالم       سالم و پلمپ
# 4800    4000    سالم و بی خط و خش             سالم       سالم و پلمپ
# 5913   89000    سالم و بی خط و خش             سالم       سالم و پلمپ
# 6098   86000    سالم و بی خط و خش             سالم       سالم و پلمپ
# 7455  340000    سالم و بی خط و خش             سالم       سالم و پلمپ
# 7921  300000    سالم و بی خط و خش             سالم       سالم و پلمپ
# 8183  500000         خط و خش جزیی             سالم       سالم و پلمپ
# 8195    3000             تمام رنگ    نیاز به تعمیر       سالم و پلمپ
# 9276  100000               دوررنگ    نیاز به تعمیر       سالم و پلمپ
#
#       insurance_time_to_expire   gearbox fuel_type       price  model
# 936                          3   دنده ای  gasoline    90000000  other
# 1422                        11  اتوماتیک  gasoline   690000000  other
# 1775                         9   دنده ای  gasoline   280000000  other
# 2259                        11   دنده ای  gasoline    90000000  other
# 2515                        10  اتوماتیک  gasoline   650000000  other
# 2905                         6   دنده ای  gasoline    45000000  other
# 2993                        11  اتوماتیک  gasoline  1520000000  other
# 3817                         5   دنده ای  gasoline   180000000  other
# 4800                        11  اتوماتیک  gasoline  1605000000  other
# 5913                        10  اتوماتیک  gasoline  1480000000  other
# 6098                         8  اتوماتیک  gasoline  1140000000  other
# 7455                         1   دنده ای  gasoline   115000000  other
# 7921                        12   دنده ای  gasoline    60000000  other
# 8183                         8   دنده ای  gasoline    45000000  other
# 8195                         3   دنده ای  gasoline    30000000  other
# 9276                         1   دنده ای  gasoline    45000000  other

# %%
#Convert Christian year to Shamsy year
data['shamsy_year'] = data['production_year']
data.loc[data['shamsy_year'] > 1900, 'shamsy_year'] = data.loc[data['shamsy_year'] > 1900, 'shamsy_year'] - 621
print(data['shamsy_year'].min())
print(data['shamsy_year'].max())
# Out:
# 1370
# 1400

# %%
#Create new feature based on production year
data['age'] = 1401 - data['shamsy_year']
#Check the results
print(np.sum(data['age'].isnull()))
data.head()
# Out:
# 0
#    no       time    city                   brand  production_year    color
# 0   1 2022-03-26  Tehran     PEUGEOT 405 GLX GAS             1393  نقره ای  \
# 1   2 2022-03-05  Tehran       PEUGEOT 206 SD V8             1393     سفید
# 2   3 2022-03-26  Tehran      PEUGEOT 206 Type 2             1397     سفید
# 3   4 2022-03-19  Tehran  PEUGEOT 207i AUTOMATIC             1390     سفید
# 4   5 2022-03-19  Tehran     PEUGEOT 207i MANUAL             1396     سفید
#
#        km     body_condition engine_condition chassis_condition
# 0   80000  سالم و بی خط و خش             سالم       سالم و پلمپ  \
# 1   85000       خط و خش جزیی             سالم       سالم و پلمپ
# 2   46000       خط و خش جزیی             سالم       سالم و پلمپ
# 3  165000  سالم و بی خط و خش             سالم       سالم و پلمپ
# 4   50000  سالم و بی خط و خش             سالم       سالم و پلمپ
#
#    insurance_time_to_expire   gearbox fuel_type      price model  shamsy_year
# 0                         9   دنده ای  gasoline  187000000   405         1393  \
# 1                         4   دنده ای  gasoline  215000000   206         1393
# 2                        12   دنده ای  gasoline  220000000   206         1397
# 3                         5  اتوماتیک  gasoline  275000000  207i         1390
# 4                         7   دنده ای  gasoline  310000000  207i         1396
#
#    age
# 0    8
# 1    8
# 2    4
# 3   11
# 4    5

# %%
#Reduce the number of levels in color
round(data['color'].value_counts() / data.shape[0] * 100, 2)
# Out:
# color
# سفید          45.56
# نقره ای       13.76
# خاکستری       11.94
# مشکی           5.94
# نوک مدادی      5.18
# یشمی           3.45
# سفید صدفی      2.69
# دلفینی         2.59
# زرد            1.90
# بژ             1.06
# سبز            1.02
# نقرآبی         0.71
# آبی            0.66
# عنابی          0.46
# طوسی           0.40
# عدسی           0.38
# قرمز           0.36
# بادمجانی       0.34
# آلبالویی       0.32
# سرمه ای        0.28
# گیلاسی         0.21
# ذغالی          0.16
# اطلسی          0.11
# بنفش           0.08
# زیتونی         0.08
# تیتانیوم       0.06
# قهوه ای        0.05
# سربی           0.05
# زرشکی          0.04
# نارنجی         0.03
# مسی            0.02
# طلایی          0.02
# کربن بلک       0.02
# برنز           0.02
# پوست پیازی     0.01
# خاکی           0.01
# Name: count, dtype: float64

# %%
#Main colors
data['color_levels'] = data['color'].replace(['سفید',
                                              'نقره ای',
                                              'خاکستری',
                                              'مشکی',                                     
                                              'نوک مدادی'],
                                             ['white',
                                              'silver',
                                              'gray',
                                              'black',                                             
                                              'graphite gray'],
                                            inplace = False)

#Other colors
data.loc[~ data['color_levels'].isin(['white',
                                      'silver',
                                      'gray',
                                      'black',                                             
                                      'graphite gray']), 'color_levels'] = 'other'

#Check the results
print(np.sum(data['color_levels'].isnull()))
data['color_levels'].value_counts()
# Out:
# 0
# color_levels
# white            4334
# other            1675
# silver           1309
# gray             1136
# black             565
# graphite gray     493
# Name: count, dtype: int64

# %%
#Convert body_condition into numeric variable
data['b_cond'] = data['body_condition'].replace(['سالم و بی خط و خش',
                                                 'خط و خش جزیی',
                                                 'صافکاری بی رنگ، در ۱ ناحیه',
                                                 'صافکاری بی رنگ، در ۲ ناحیه',
                                                 'صافکاری بی رنگ، در ۳ ناحیه',
                                                 'صافکاری بی رنگ، در ۴ ناحیه',
                                                 'صافکاری بی رنگ، در ۵ ناحیه',
                                                 'صافکاری بی رنگ، در ۶ ناحیه',
                                                 'صافکاری بی رنگ، در ۹ ناحیه',
                                                 'صافکاری بی رنگ، در ۱۰ ناحیه',
                                                 'رنگ شدگی در ۱ ناحیه',
                                                 'رنگ شدگی در ۲ ناحیه',
                                                 'رنگ شدگی در ۳ ناحیه',
                                                 'رنگ شدگی در ۴ ناحیه',
                                                 'رنگ شدگی در ۵ ناحیه',
                                                 'رنگ شدگی در ۶ ناحیه',       
                                                 'رنگ شدگی در ۷ ناحیه',  
                                                 'رنگ شدگی در ۸ ناحیه',    
                                                 'رنگ شدگی در ۹ ناحیه',
                                                 'رنگ شدگی در ۱۰ ناحیه',
                                                 'دوررنگ',
                                                 'تمام رنگ',
                                                 'اوراقی'],
                                                 list(range(1, 24)), inplace = False)

#Check the results
print(np.sum(data['b_cond'].isnull()))
data['b_cond'].describe()
# Out:
# 0
# count    9512.000000
# mean        4.455635
# std         6.260655
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        23.000000
# Name: b_cond, dtype: float64

# %%
#Convert Persian language into English for engine_condition
data['e_cond'] = data['engine_condition'].replace(['سالم',
                                                   'تعویض شده',
                                                   'نیاز به تعمیر'], 
                                                  ['A', 'B', 'C'], inplace = False)

#Check the results
print(np.sum(data['e_cond'].isnull()))
data['e_cond'].value_counts()
# Out:
# 0
# e_cond
# A    9405
# C      65
# B      42
# Name: count, dtype: int64

# %%
#Convert Persian language into English for chassis_condition
data['c_cond'] = data['chassis_condition'].replace(['سالم و پلمپ',
                                                    'ضربه خورده',
                                                    'رنگ شده'], 
                                                   ['A', 'B', 'C'], inplace = False)

#Check the results
print(np.sum(data['c_cond'].isnull()))
data['c_cond'].value_counts()
# Out:
# 0
# c_cond
# A    9381
# B     116
# C      15
# Name: count, dtype: int64

# %%
#Convert Persian language into English for gearbox
data['if_automatic'] = data['gearbox'].replace(['دنده ای', 
                                                'اتوماتیک'], 
                                               ['no', 'yes'], inplace = False)

#Check the results
print(np.sum(data['if_automatic'].isnull()))
data['if_automatic'].value_counts()
# Out:
# 0
# if_automatic
# no     8897
# yes     615
# Name: count, dtype: int64

# %%
#Check for outliers
plt.boxplot(data['price'])
plt.show()

# %%
#Boxplot for multiple groups
plt.boxplot([data.loc[data['model'] == '2008', 'price'], 
             data.loc[data['model'] == '206', 'price'],
             data.loc[data['model'] == '207i', 'price'],
             data.loc[data['model'] == '405', 'price'],
             data.loc[data['model'] == '407', 'price'],
             data.loc[data['model'] == 'PARS', 'price'],
             data.loc[data['model'] == 'RD', 'price'],
             data.loc[data['model'] == 'RDI', 'price'],
             data.loc[data['model'] == 'ROA', 'price'],
             data.loc[data['model'] == 'other', 'price']])
plt.title('Boxplot of Price vs. Models')
plt.xticks(ticks = list(range(1, 11)), 
           labels = ['2008', '206', '207i', '405', '407', 'PARS', 'RD', 'RDI', 'ROA', 'other'])
plt.xlabel('Model')
plt.ylabel('Price')
plt.show()

# %%
data.groupby('model')['price'].describe()
# Out:
#         count          mean           std          min          25%
# model
# 2008     43.0  9.445581e+08  8.129233e+07  795000000.0  892500000.0  \
# 206    2944.0  2.230163e+08  5.189852e+07   11000000.0  200000000.0
# 207i    888.0  3.709107e+08  6.526604e+07   10000000.0  337000000.0
# 405    3093.0  1.651462e+08  8.075183e+07   11111111.0  116000000.0
# 407      20.0  4.593500e+08  6.203163e+07  330000000.0  433750000.0
# PARS   1821.0  2.428981e+08  8.339237e+07   75000000.0  195000000.0
# RD      350.0  4.627571e+07  1.065170e+07   20000000.0   39000000.0
# RDI      48.0  5.612500e+07  1.175526e+07   39000000.0   47750000.0
# ROA     289.0  7.931073e+07  9.571477e+07   38000000.0   63000000.0
# other    16.0  5.040625e+08  5.978049e+08   30000000.0   56250000.0
#
#                50%          75%           max
# model
# 2008   933000000.0  990000000.0  1.150000e+09
# 206    230000000.0  258000000.0  3.300000e+08
# 207i   363500000.0  395000000.0  5.550000e+08
# 405    163000000.0  210000000.0  3.000000e+09
# 407    452500000.0  488000000.0  6.200000e+08
# PARS   253000000.0  281500000.0  2.580000e+09
# RD      45000000.0   52000000.0  1.000000e+08
# RDI     55000000.0   61500000.0  1.000000e+08
# ROA     70000000.0   79000000.0  1.500000e+09
# other  147500000.0  802500000.0  1.605000e+09

# %%
#Outlier detection using Tukey's method
from scipy.stats import iqr
def outlier_detector(df, colname = 'price'):
    #Calculate lower band and upper bound for Tukey's method
    lb = np.quantile(df[colname], 0.25) - 1.5 * iqr(df[colname])
    ub = np.quantile(df[colname], 0.75) + 1.5 * iqr(df[colname])
    #Return rows w/ outliers in colname
    return df.loc[(df[colname] > ub) | (df[colname] < lb), :]

# %%
#Check outliers for 206
pd.set_option('display.max_rows', 200)
outlier_detector(df = data.loc[data['model'] == '206', :])
#Note: check index 1209
# Out:
#         no       time     city               brand  production_year
# 57      58 2022-03-12   Tehran  PEUGEOT 206 Type 2             1387  \
# 85      86 2022-03-19   Tehran  PEUGEOT 206 Type 2             1382
# 112    113 2022-03-12   Tehran  PEUGEOT 206 Type 2             1385
# 303    304 2022-03-19   Tehran  PEUGEOT 206 Type 2             1382
# 318    319 2022-03-05   Tehran  PEUGEOT 206 Type 2             1383
# 381    382 2022-03-26   Tehran  PEUGEOT 206 Type 4             1381
# 382    383 2022-04-02   Tehran  PEUGEOT 206 Type 2             1383
# 393    394 2022-03-05   Tehran  PEUGEOT 206 Type 2             1384
# 466    467 2022-03-30   Tehran  PEUGEOT 206 Type 2             1383
# 487    488 2022-03-12   Tehran  PEUGEOT 206 Type 2             1384
# 491    492 2022-03-12   Tehran  PEUGEOT 206 Type 3             1383
# 559    560 2022-03-12   Tehran  PEUGEOT 206 Type 2             1383
# 574    575 2022-03-05   Tehran  PEUGEOT 206 Type 3             1382
# 579    580 2022-03-26   Tehran  PEUGEOT 206 Type 2             1383
# 619    620 2022-03-12   Tehran  PEUGEOT 206 Type 2             1383
# 637    638 2022-03-19   Tehran  PEUGEOT 206 Type 1             1380
# 719    720 2022-04-02   Tehran  PEUGEOT 206 Type 2             1381
# 792    793 2022-03-12   Tehran  PEUGEOT 206 Type 2             1382
# 843    844 2022-03-05   Tehran  PEUGEOT 206 Type 2             1384
# 869    870 2022-03-19   Tehran  PEUGEOT 206 Type 2             1383
# 1119  1120 2022-03-12   Tehran  PEUGEOT 206 Type 2             1385
# 1184  1185 2022-03-26   Tehran  PEUGEOT 206 Type 2             1385
# 1194  1195 2022-03-19   Tehran  PEUGEOT 206 Type 2             1383
# 1209  1210 2022-03-26   Tehran  PEUGEOT 206 Type 1             1381
# 1347  1348 2022-04-02   Tehran  PEUGEOT 206 Type 2             1380
# 1583  1584 2022-03-26   Tehran  PEUGEOT 206 Type 2             1383
# 1601  1602 2022-03-29   Tehran  PEUGEOT 206 Type 2             1382
# 1694  1695 2022-03-26   Tehran  PEUGEOT 206 Type 2             1383
# 1799  1800 2022-03-05   Tehran  PEUGEOT 206 Type 2             1383
# 1863  1864 2022-03-12   Tehran  PEUGEOT 206 Type 5             1383
# 1870  1871 2022-03-12   Tehran  PEUGEOT 206 Type 2             1385
# 1965  1966 2022-03-26   Tehran  PEUGEOT 206 Type 2             1382
# 2329  2330 2022-03-05   Tehran  PEUGEOT 206 Type 2             1381
# 2385  2386 2022-03-05   Tehran  PEUGEOT 206 Type 2             1382
# 2550  2551 2022-03-05   Tehran  PEUGEOT 206 Type 2             1383
# 2554  2555 2022-03-19   Tehran  PEUGEOT 206 Type 3             1385
# 2662  2663 2022-03-26   Tehran  PEUGEOT 206 Type 2             1383
# 2824  2825 2022-03-12   Tehran  PEUGEOT 206 Type 3             1383
# 2858  2859 2022-03-12   Tehran  PEUGEOT 206 Type 2             1382
# 2917  2918 2022-03-05   Tehran  PEUGEOT 206 Type 2             1383
# 2925  2926 2022-03-19   Tehran  PEUGEOT 206 Type 2             1382
# 2959  2960 2022-03-12   Tehran  PEUGEOT 206 Type 2             1383
# 3038  3039 2022-03-05   Tehran  PEUGEOT 206 Type 2             1384
# 3272  3273 2022-04-02   Tehran  PEUGEOT 206 Type 3             1382
# 3370  3371 2022-03-12   Tehran  PEUGEOT 206 Type 2             1384
# 3469  3470 2022-03-19   Tehran  PEUGEOT 206 Type 2             1384
# 3570  3571 2022-03-12   Tehran  PEUGEOT 206 Type 2             1385
# 3725  3726 2022-03-26   Tehran  PEUGEOT 206 Type 2             1383
# 3756  3757 2022-03-19   Tehran  PEUGEOT 206 Type 2             1383
# 3762  3763 2022-03-12   Tehran  PEUGEOT 206 Type 1             1380
# 3795  3796 2022-03-19   Tehran  PEUGEOT 206 Type 2             1383
# 3804  3805 2022-03-19   Tehran  PEUGEOT 206 Type 1             1380
# 3806  3807 2022-03-26   Tehran  PEUGEOT 206 Type 2             1383
# 3889  3890 2022-03-12   Tehran  PEUGEOT 206 Type 2             1383
# 3965  3966 2022-03-27   Tehran  PEUGEOT 206 Type 2             1382
# 3982  3983 2022-03-19   Tehran  PEUGEOT 206 Type 2             1383
# 4065  4066 2022-03-26   Tehran  PEUGEOT 206 Type 1             1380
# 4087  4088 2022-03-19   Tehran  PEUGEOT 206 Type 3             1382
# 4402  4403 2022-03-19   Tehran  PEUGEOT 206 Type 2             1381
# 4482  4483 2022-03-19   Tehran  PEUGEOT 206 Type 3             1382
# 4529  4530 2022-03-27   Tehran  PEUGEOT 206 Type 2             1382
# 4608  4609 2022-03-12   Tehran  PEUGEOT 206 Type 2             1383
# 4708  4709 2022-03-05   Tehran  PEUGEOT 206 Type 2             1384
# 4942  4943 2022-03-12   Tehran  PEUGEOT 206 Type 5             1383
# 4956  4957 2022-03-12   Tehran  PEUGEOT 206 Type 2             1382
# 5101  5102 2022-03-19  Mashhad  PEUGEOT 206 Type 2             1383
# 5107  5108 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1385
# 5170  5171 2022-03-12  Mashhad  PEUGEOT 206 Type 2             1383
# 5273  5274 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1381
# 5325  5326 2022-03-19  Mashhad  PEUGEOT 206 Type 2             1383
# 5364  5365 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1384
# 5383  5384 2022-03-12  Mashhad  PEUGEOT 206 Type 2             1382
# 5431  5432 2022-03-30  Mashhad  PEUGEOT 206 Type 2             1383
# 5435  5436 2022-03-26  Mashhad  PEUGEOT 206 Type 1             1381
# 5446  5447 2022-04-02  Mashhad  PEUGEOT 206 Type 2             1383
# 5459  5460 2022-03-27  Mashhad  PEUGEOT 206 Type 2             1383
# 5476  5477 2022-03-30  Mashhad  PEUGEOT 206 Type 2             1383
# 5670  5671 2022-03-27  Mashhad  PEUGEOT 206 Type 2             1380
# 5682  5683 2022-03-05  Mashhad  PEUGEOT 206 Type 2             1385
# 5735  5736 2022-03-27  Mashhad  PEUGEOT 206 Type 2             1383
# 5747  5748 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1383
# 5782  5783 2022-03-30  Mashhad  PEUGEOT 206 Type 2             1383
# 5813  5814 2022-03-12  Mashhad  PEUGEOT 206 Type 2             1383
# 5818  5819 2022-03-29  Mashhad  PEUGEOT 206 Type 2             1382
# 5838  5839 2022-03-19  Mashhad  PEUGEOT 206 Type 2             1383
# 5892  5893 2022-03-29  Mashhad  PEUGEOT 206 Type 1             1380
# 5915  5916 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1383
# 5942  5943 2022-03-29  Mashhad  PEUGEOT 206 Type 2             1380
# 5958  5959 2022-03-29  Mashhad  PEUGEOT 206 Type 2             1382
# 6038  6039 2022-03-26  Mashhad  PEUGEOT 206 Type 1             1380
# 6076  6077 2022-03-26  Mashhad  PEUGEOT 206 Type 1             1380
# 6078  6079 2022-03-05  Mashhad  PEUGEOT 206 Type 2             1382
# 6097  6098 2022-03-05  Mashhad  PEUGEOT 206 Type 2             1381
# 6123  6124 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1383
# 6167  6168 2022-03-27  Mashhad  PEUGEOT 206 Type 2             1381
# 6172  6173 2022-03-19  Mashhad  PEUGEOT 206 Type 5             1386
# 6190  6191 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1382
# 6213  6214 2022-03-30  Mashhad  PEUGEOT 206 Type 2             1384
# 6293  6294 2022-04-02  Mashhad  PEUGEOT 206 Type 1             1380
# 6389  6390 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1383
# 6402  6403 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1381
# 6442  6443 2022-03-19  Mashhad  PEUGEOT 206 Type 2             1384
# 6444  6445 2022-03-12  Mashhad  PEUGEOT 206 Type 2             1383
# 6499  6500 2022-03-28  Mashhad  PEUGEOT 206 Type 2             1383
# 6501  6502 2022-03-31  Mashhad  PEUGEOT 206 Type 2             1383
# 6530  6531 2022-03-29  Mashhad  PEUGEOT 206 Type 3             1382
# 6575  6576 2022-03-28  Mashhad  PEUGEOT 206 Type 1             1380
# 6591  6592 2022-03-30  Mashhad  PEUGEOT 206 Type 2             1383
# 6635  6636 2022-03-12  Mashhad  PEUGEOT 206 Type 2             1381
# 6639  6640 2022-03-26  Mashhad  PEUGEOT 206 Type 2             1381
# 6677  6678 2022-03-19  Mashhad  PEUGEOT 206 Type 2             1381
# 6734  6735 2022-03-19  Isfahan  PEUGEOT 206 Type 2             1386
# 6843  6844 2022-03-05  Isfahan  PEUGEOT 206 Type 2             1382
# 6852  6853 2022-03-30  Isfahan  PEUGEOT 206 Type 2             1384
# 6865  6866 2022-03-29  Isfahan  PEUGEOT 206 Type 2             1385
# 6888  6889 2022-03-26  Isfahan  PEUGEOT 206 Type 2             1382
# 6951  6952 2022-03-05  Isfahan  PEUGEOT 206 Type 3             1384
# 6985  6986 2022-03-26  Isfahan  PEUGEOT 206 Type 2             1382
# 7000  7001 2022-03-19  Isfahan  PEUGEOT 206 Type 2             1382
# 7019  7020 2022-03-26  Isfahan  PEUGEOT 206 Type 2             1384
# 7046  7047 2022-03-30  Isfahan  PEUGEOT 206 Type 1             1380
# 7056  7057 2022-03-30  Isfahan  PEUGEOT 206 Type 1             1380
# 7081  7082 2022-03-29  Isfahan  PEUGEOT 206 Type 2             1383
# 7085  7086 2022-03-12  Isfahan  PEUGEOT 206 Type 2             1382
# 7088  7089 2022-03-12  Isfahan  PEUGEOT 206 Type 2             1383
# 7193  7194 2022-03-19  Isfahan  PEUGEOT 206 Type 2             1382
# 7196  7197 2022-03-26  Isfahan  PEUGEOT 206 Type 2             1384
# 7236  7237 2022-03-27  Isfahan  PEUGEOT 206 Type 2             1383
# 7243  7244 2022-03-26  Isfahan  PEUGEOT 206 Type 2             1383
# 7247  7248 2022-03-19  Isfahan  PEUGEOT 206 Type 2             1387
# 7281  7282 2022-03-26  Isfahan  PEUGEOT 206 Type 2             1386
# 7364  7365 2022-03-05  Isfahan  PEUGEOT 206 Type 2             1382
# 7386  7387 2022-03-19  Isfahan  PEUGEOT 206 Type 2             1383
# 7469  7470 2022-03-05  Isfahan  PEUGEOT 206 Type 2             1384
# 7581  7582 2022-03-12  Isfahan  PEUGEOT 206 Type 1             1380
# 7612  7613 2022-03-19  Isfahan  PEUGEOT 206 Type 2             1381
# 7745  7746 2022-03-05  Isfahan  PEUGEOT 206 Type 1             1380
# 7811  7812 2022-03-19  Isfahan  PEUGEOT 206 Type 2             1382
# 7860  7861 2022-03-26  Isfahan  PEUGEOT 206 Type 2             1383
# 7885  7886 2022-03-12  Isfahan  PEUGEOT 206 Type 2             1384
# 7929  7930 2022-03-19  Isfahan  PEUGEOT 206 Type 2             1384
# 8034  8035 2022-03-26  Isfahan  PEUGEOT 206 Type 2             1381
# 8052  8053 2022-03-12  Isfahan  PEUGEOT 206 Type 2             1382
# 8077  8078 2022-03-26  Isfahan  PEUGEOT 206 Type 2             1381
# 8245  8246 2022-03-27   Shiraz  PEUGEOT 206 Type 2             1386
# 8264  8265 2022-03-30   Shiraz  PEUGEOT 206 Type 2             1383
# 8312  8313 2022-03-12   Shiraz  PEUGEOT 206 Type 2             1385
# 8352  8353 2022-03-26   Shiraz  PEUGEOT 206 Type 2             1384
# 8529  8530 2022-03-12   Shiraz  PEUGEOT 206 Type 2             1386
# 8594  8595 2022-03-26   Shiraz  PEUGEOT 206 Type 2             1382
# 8649  8650 2022-03-05   Shiraz  PEUGEOT 206 Type 2             1382
# 8679  8680 2022-03-26   Shiraz  PEUGEOT 206 Type 2             1383
# 8718  8719 2022-03-12   Shiraz  PEUGEOT 206 Type 2             1382
# 8796  8797 2022-03-19   Shiraz  PEUGEOT 206 Type 1             1380
# 8882  8883 2022-03-12   Shiraz  PEUGEOT 206 Type 3             1383
# 8921  8922 2022-03-29   Shiraz  PEUGEOT 206 Type 2             1383
# 8960  8961 2022-03-30   Shiraz  PEUGEOT 206 Type 2             1386
# 9097  9098 2022-03-05   Shiraz  PEUGEOT 206 Type 2             1383
# 9141  9142 2022-03-05   Shiraz  PEUGEOT 206 Type 2             1383
# 9181  9182 2022-03-28   Shiraz  PEUGEOT 206 Type 2             1383
# 9197  9198 2022-03-05   Shiraz  PEUGEOT 206 Type 2             1381
# 9389  9390 2022-03-12   Shiraz  PEUGEOT 206 Type 5             1384
# 9411  9412 2022-03-26   Shiraz  PEUGEOT 206 Type 2             1385
#
#           color      km              body_condition engine_condition
# 57    نوک مدادی  293563                خط و خش جزیی             سالم  \
# 85      نقره ای  260000                خط و خش جزیی             سالم
# 112     نقره ای  329000                خط و خش جزیی             سالم
# 303        یشمی  450000           سالم و بی خط و خش             سالم
# 318     نقره ای  287700                      دوررنگ             سالم
# 381        مشکی  338228                خط و خش جزیی             سالم
# 382     نقره ای  390000                خط و خش جزیی             سالم
# 393          بژ  320000                خط و خش جزیی             سالم
# 466     نقره ای  400000         رنگ شدگی در ۱ ناحیه    نیاز به تعمیر
# 487        مشکی  400000           سالم و بی خط و خش             سالم
# 491     نقره ای  269000                خط و خش جزیی             سالم
# 559          بژ  404000                      دوررنگ             سالم
# 574     نقره ای  298000                      دوررنگ             سالم
# 579     نقره ای  330000                خط و خش جزیی             سالم
# 619        مشکی  310000                خط و خش جزیی             سالم
# 637        مشکی  400000           سالم و بی خط و خش             سالم
# 719        یشمی     220           سالم و بی خط و خش             سالم
# 792     نقره ای  420000                      دوررنگ             سالم
# 843        مشکی   50000           سالم و بی خط و خش             سالم
# 869     نقره ای  400000         رنگ شدگی در ۱ ناحیه             سالم
# 1119      طلایی  250000           سالم و بی خط و خش             سالم
# 1184       مشکی  400000           سالم و بی خط و خش             سالم
# 1194  نوک مدادی     333                      دوررنگ             سالم
# 1209       مشکی       0                      اوراقی    نیاز به تعمیر
# 1347       مشکی  300000                خط و خش جزیی             سالم
# 1583     نقرآبی  325000                خط و خش جزیی             سالم
# 1601      ذغالی  220000         رنگ شدگی در ۳ ناحیه    نیاز به تعمیر
# 1694       مشکی  180000                خط و خش جزیی             سالم
# 1799    نقره ای  250000           سالم و بی خط و خش             سالم
# 1863    نقره ای  310000                      دوررنگ             سالم
# 1870  نوک مدادی  220000                خط و خش جزیی             سالم
# 1965     نقرآبی  350000         رنگ شدگی در ۱ ناحیه             سالم
# 2329      اطلسی  320000                      دوررنگ             سالم
# 2385   آلبالویی       0                      دوررنگ    نیاز به تعمیر
# 2550    خاکستری  300000                    تمام رنگ             سالم
# 2554    نقره ای  276700                      دوررنگ             سالم
# 2662       مشکی  350000         رنگ شدگی در ۳ ناحیه             سالم
# 2824    نقره ای  269000           سالم و بی خط و خش             سالم
# 2858    نقره ای  290000                      دوررنگ             سالم
# 2917    نقره ای       1                      دوررنگ             سالم
# 2925    نقره ای  290000                      دوررنگ             سالم
# 2959         بژ  300000                خط و خش جزیی             سالم
# 3038    نقره ای  195000                خط و خش جزیی             سالم
# 3272         بژ  150000                      دوررنگ             سالم
# 3370    نقره ای  280000                      دوررنگ             سالم
# 3469    نقره ای  400000                      دوررنگ             سالم
# 3570    نقره ای     240                      دوررنگ             سالم
# 3725    نقره ای  250000                      دوررنگ             سالم
# 3756         بژ  500000                    تمام رنگ             سالم
# 3762       یشمی  240000         رنگ شدگی در ۳ ناحیه             سالم
# 3795    نقره ای      20                      دوررنگ             سالم
# 3804       مشکی  300000           سالم و بی خط و خش             سالم
# 3806    نقره ای  365000           سالم و بی خط و خش             سالم
# 3889    نقره ای  311000                      دوررنگ             سالم
# 3965    نقره ای     338                      دوررنگ             سالم
# 3982  نوک مدادی  220000         رنگ شدگی در ۱ ناحیه             سالم
# 4065       یشمی  430000                    تمام رنگ        تعویض شده
# 4087    نقره ای  230000                خط و خش جزیی             سالم
# 4402       مشکی  300000  صافکاری بی رنگ، در ۳ ناحیه             سالم
# 4482    نقره ای  287000                      دوررنگ             سالم
# 4529    نقره ای  300000           سالم و بی خط و خش             سالم
# 4608   آلبالویی     400                خط و خش جزیی             سالم
# 4708         بژ  190000                خط و خش جزیی             سالم
# 4942    نقره ای  300000                    تمام رنگ             سالم
# 4956       یشمی  100000                    تمام رنگ             سالم
# 5101     دلفینی   27500           سالم و بی خط و خش             سالم
# 5107    نقره ای  350000                    تمام رنگ             سالم
# 5170         بژ  380000                خط و خش جزیی             سالم
# 5273    نقره ای  391000                خط و خش جزیی             سالم
# 5325     نقرآبی  260000                      دوررنگ             سالم
# 5364    نقره ای  440000                خط و خش جزیی             سالم
# 5383   آلبالویی  300000         رنگ شدگی در ۱ ناحیه             سالم
# 5431       قرمز  349000                    تمام رنگ             سالم
# 5435   آلبالویی   65000                    تمام رنگ    نیاز به تعمیر
# 5446    نقره ای  350000           سالم و بی خط و خش             سالم
# 5459    نقره ای  300000           سالم و بی خط و خش             سالم
# 5476         بژ  348100                    تمام رنگ             سالم
# 5670       سفید  110000                    تمام رنگ             سالم
# 5682     دلفینی  250000                خط و خش جزیی             سالم
# 5735    نقره ای  499000                خط و خش جزیی             سالم
# 5747    نقره ای  380000                      دوررنگ             سالم
# 5782       یشمی  300000                      دوررنگ             سالم
# 5813    نقره ای  123456                      دوررنگ    نیاز به تعمیر
# 5818       یشمی  500000                    تمام رنگ             سالم
# 5838    خاکستری  295000                خط و خش جزیی             سالم
# 5892       مشکی  500000                خط و خش جزیی             سالم
# 5915         بژ  350000                    تمام رنگ             سالم
# 5942       مشکی  100000           سالم و بی خط و خش             سالم
# 5958       یشمی  390000                خط و خش جزیی             سالم
# 6038       مشکی  320000                    تمام رنگ             سالم
# 6076       قرمز  200000                    تمام رنگ             سالم
# 6078    نقره ای  111120                خط و خش جزیی             سالم
# 6097       مشکی  270000                خط و خش جزیی             سالم
# 6123         بژ  280000                      دوررنگ             سالم
# 6167       یشمی  390000         رنگ شدگی در ۲ ناحیه             سالم
# 6172  نوک مدادی  320000                    تمام رنگ             سالم
# 6190       سفید  123456                    تمام رنگ             سالم
# 6213         بژ  300000                      دوررنگ             سالم
# 6293     زیتونی  500000                      دوررنگ             سالم
# 6389    نقره ای  469000                      دوررنگ             سالم
# 6402       یشمی  500000                خط و خش جزیی             سالم
# 6442    نقره ای  270000                      دوررنگ             سالم
# 6444    نقره ای  380000         رنگ شدگی در ۲ ناحیه             سالم
# 6499     نقرآبی  296008                خط و خش جزیی             سالم
# 6501   تیتانیوم  190000           سالم و بی خط و خش             سالم
# 6530       مشکی  300000         رنگ شدگی در ۲ ناحیه             سالم
# 6575   آلبالویی  300000                      دوررنگ             سالم
# 6591         بژ  356000                خط و خش جزیی             سالم
# 6635  سفید صدفی       4                      دوررنگ             سالم
# 6639       یشمی  400000                خط و خش جزیی             سالم
# 6677       مشکی  250000                      دوررنگ             سالم
# 6734    قهوه ای  200000                      دوررنگ             سالم
# 6843     نقرآبی  490000         رنگ شدگی در ۲ ناحیه             سالم
# 6852       مشکی  310000         رنگ شدگی در ۲ ناحیه             سالم
# 6865  نوک مدادی  289999                    تمام رنگ             سالم
# 6888       یشمی  250000                خط و خش جزیی             سالم
# 6951        آبی  330000                    تمام رنگ             سالم
# 6985       یشمی  220000           سالم و بی خط و خش             سالم
# 7000       یشمی  100000                      دوررنگ             سالم
# 7019     نقرآبی  340000                      دوررنگ             سالم
# 7046       سفید  245000                      دوررنگ             سالم
# 7056       مشکی  457000                    تمام رنگ             سالم
# 7081         بژ  400000                      دوررنگ             سالم
# 7085       یشمی  400000                      دوررنگ             سالم
# 7088  نوک مدادی  450000         رنگ شدگی در ۲ ناحیه             سالم
# 7193       قرمز  350000                خط و خش جزیی             سالم
# 7196  نوک مدادی  450000         رنگ شدگی در ۲ ناحیه             سالم
# 7236    نقره ای  400000         رنگ شدگی در ۲ ناحیه             سالم
# 7243  نوک مدادی   39000                      دوررنگ             سالم
# 7247    نقره ای  345000           سالم و بی خط و خش             سالم
# 7281    خاکستری  490000                    تمام رنگ    نیاز به تعمیر
# 7364     نقرآبی  300000           سالم و بی خط و خش             سالم
# 7386    نقره ای   11111         رنگ شدگی در ۵ ناحیه             سالم
# 7469    نقره ای       1                      دوررنگ             سالم
# 7581      اطلسی  143000         رنگ شدگی در ۲ ناحیه             سالم
# 7612       مشکی   61090                    تمام رنگ             سالم
# 7745  سفید صدفی  400000                    تمام رنگ             سالم
# 7811    نقره ای  300000                      دوررنگ             سالم
# 7860      زرشکی  344000         رنگ شدگی در ۱ ناحیه             سالم
# 7885    نقره ای  288000                    تمام رنگ             سالم
# 7929         بژ  300000  صافکاری بی رنگ، در ۱ ناحیه             سالم
# 8034       یشمی       0                      دوررنگ             سالم
# 8052  نوک مدادی  330000         رنگ شدگی در ۱ ناحیه             سالم
# 8077         بژ       0                      دوررنگ             سالم
# 8245  نوک مدادی  420000                خط و خش جزیی             سالم
# 8264    نقره ای  265000                      دوررنگ             سالم
# 8312    نقره ای  170000                      دوررنگ             سالم
# 8352    نقره ای  380000  صافکاری بی رنگ، در ۲ ناحیه             سالم
# 8529     دلفینی  280000                      دوررنگ             سالم
# 8594    نقره ای  500000           سالم و بی خط و خش             سالم
# 8649    نقره ای   46085                      دوررنگ             سالم
# 8679    نقره ای  380000                خط و خش جزیی             سالم
# 8718    نقره ای  130000                      دوررنگ             سالم
# 8796       سفید  200000                    تمام رنگ             سالم
# 8882    خاکستری  250000                      دوررنگ             سالم
# 8921         بژ  490000                خط و خش جزیی             سالم
# 8960  نوک مدادی  370000                      دوررنگ             سالم
# 9097    خاکستری  500000                خط و خش جزیی             سالم
# 9141    نقره ای       0                      دوررنگ             سالم
# 9181    نقره ای  180000                خط و خش جزیی    نیاز به تعمیر
# 9197       سفید  100000                      دوررنگ             سالم
# 9389    نقره ای  370000                خط و خش جزیی             سالم
# 9411    نقره ای  148000           سالم و بی خط و خش             سالم
#
#      chassis_condition  ...  fuel_type      price model  shamsy_year age
# 57         سالم و پلمپ  ...   gasoline  112000000   206         1387  14  \
# 85         سالم و پلمپ  ...   gasoline   94000000   206         1382  19
# 112        سالم و پلمپ  ...   gasoline  110000000   206         1385  16
# 303        سالم و پلمپ  ...   gasoline   85700000   206         1382  19
# 318         ضربه خورده  ...   gasoline   83000000   206         1383  18
# 381        سالم و پلمپ  ...   gasoline  100000000   206         1381  20
# 382        سالم و پلمپ  ...   gasoline  100000000   206         1383  18
# 393        سالم و پلمپ  ...   gasoline  100000000   206         1384  17
# 466        سالم و پلمپ  ...   gasoline   95000000   206         1383  18
# 487        سالم و پلمپ  ...   gasoline   99000000   206         1384  17
# 491        سالم و پلمپ  ...   gasoline  104000000   206         1383  18
# 559        سالم و پلمپ  ...   gasoline   88000000   206         1383  18
# 574         ضربه خورده  ...   gasoline   88000000   206         1382  19
# 579        سالم و پلمپ  ...   gasoline   97000000   206         1383  18
# 619        سالم و پلمپ  ...   gasoline   93000000   206         1383  18
# 637        سالم و پلمپ  ...   gasoline   79000000   206         1380  21
# 719        سالم و پلمپ  ...   gasoline   96000000   206         1381  20
# 792        سالم و پلمپ  ...   gasoline   81000000   206         1382  19
# 843        سالم و پلمپ  ...   gasoline  105000000   206         1384  17
# 869        سالم و پلمپ  ...   gasoline   95000000   206         1383  18
# 1119       سالم و پلمپ  ...   gasoline  110000000   206         1385  16
# 1184       سالم و پلمپ  ...   gasoline   98000000   206         1385  16
# 1194       سالم و پلمپ  ...   gasoline  105000000   206         1383  18
# 1209       سالم و پلمپ  ...   gasoline   11000000   206         1381  20
# 1347       سالم و پلمپ  ...   gasoline   83000000   206         1380  21
# 1583       سالم و پلمپ  ...   gasoline  100000000   206         1383  18
# 1601       سالم و پلمپ  ...   gasoline   85000000   206         1382  19
# 1694       سالم و پلمپ  ...   gasoline   98000000   206         1383  18
# 1799       سالم و پلمپ  ...   gasoline   98000000   206         1383  18
# 1863        ضربه خورده  ...   gasoline   95000000   206         1383  18
# 1870       سالم و پلمپ  ...   gasoline  111000000   206         1385  16
# 1965       سالم و پلمپ  ...   gasoline   90000000   206         1382  19
# 2329       سالم و پلمپ  ...   gasoline   75000000   206         1381  20
# 2385       سالم و پلمپ  ...   gasoline   90000000   206         1382  19
# 2550       سالم و پلمپ  ...   gasoline   86000000   206         1383  18
# 2554       سالم و پلمپ  ...   gasoline  105000000   206         1385  16
# 2662       سالم و پلمپ  ...   gasoline   83000000   206         1383  18
# 2824       سالم و پلمپ  ...   gasoline  104000000   206         1383  18
# 2858        ضربه خورده  ...   gasoline   80000000   206         1382  19
# 2917       سالم و پلمپ  ...   gasoline   93000000   206         1383  18
# 2925       سالم و پلمپ  ...   gasoline   85000000   206         1382  19
# 2959       سالم و پلمپ  ...   gasoline   82000000   206         1383  18
# 3038       سالم و پلمپ  ...   gasoline  106000000   206         1384  17
# 3272       سالم و پلمپ  ...   gasoline   95000000   206         1382  19
# 3370       سالم و پلمپ  ...   gasoline   96000000   206         1384  17
# 3469       سالم و پلمپ  ...   gasoline   94500000   206         1384  17
# 3570        ضربه خورده  ...   gasoline  102000000   206         1385  16
# 3725       سالم و پلمپ  ...   gasoline   90000000   206         1383  18
# 3756       سالم و پلمپ  ...   gasoline   85000000   206         1383  18
# 3762       سالم و پلمپ  ...   gasoline   95000000   206         1380  21
# 3795       سالم و پلمپ  ...   gasoline  110000000   206         1383  18
# 3804       سالم و پلمپ  ...   gasoline   90000000   206         1380  21
# 3806       سالم و پلمپ  ...   gasoline   93000000   206         1383  18
# 3889       سالم و پلمپ  ...   gasoline   86000000   206         1383  18
# 3965       سالم و پلمپ  ...   gasoline   80000000   206         1382  19
# 3982       سالم و پلمپ  ...   gasoline   98000000   206         1383  18
# 4065       سالم و پلمپ  ...   gasoline   75000000   206         1380  21
# 4087       سالم و پلمپ  ...   gasoline   90000000   206         1382  19
# 4402       سالم و پلمپ  ...   gasoline   84000000   206         1381  20
# 4482       سالم و پلمپ  ...   gasoline   89000000   206         1382  19
# 4529       سالم و پلمپ  ...   gasoline   82000000   206         1382  19
# 4608       سالم و پلمپ  ...   gasoline   98000000   206         1383  18
# 4708       سالم و پلمپ  ...   gasoline   97000000   206         1384  17
# 4942        ضربه خورده  ...   gasoline   98000000   206         1383  18
# 4956       سالم و پلمپ  ...   gasoline   97000000   206         1382  19
# 5101        ضربه خورده  ...   gasoline  103000000   206         1383  18
# 5107       سالم و پلمپ  ...   gasoline   93500000   206         1385  16
# 5170       سالم و پلمپ  ...   gasoline   85000000   206         1383  18
# 5273       سالم و پلمپ  ...   gasoline   89000000   206         1381  20
# 5325       سالم و پلمپ  ...   gasoline   82000000   206         1383  18
# 5364       سالم و پلمپ  ...   gasoline  100000000   206         1384  17
# 5383       سالم و پلمپ  ...   gasoline   90000000   206         1382  19
# 5431       سالم و پلمپ  ...   gasoline   85000000   206         1383  18
# 5435        ضربه خورده  ...   gasoline   70000000   206         1381  20
# 5446       سالم و پلمپ  ...   gasoline  100000000   206         1383  18
# 5459       سالم و پلمپ  ...   gasoline   91000000   206         1383  18
# 5476       سالم و پلمپ  ...   gasoline   80000000   206         1383  18
# 5670       سالم و پلمپ  ...   gasoline   85000000   206         1380  21
# 5682       سالم و پلمپ  ...   gasoline  107000000   206         1385  16
# 5735       سالم و پلمپ  ...   gasoline  100000000   206         1383  18
# 5747       سالم و پلمپ  ...   gasoline   86000000   206         1383  18
# 5782       سالم و پلمپ  ...   gasoline   87000000   206         1383  18
# 5813       سالم و پلمپ  ...   gasoline   95000000   206         1383  18
# 5818       سالم و پلمپ  ...   gasoline   78000000   206         1382  19
# 5838       سالم و پلمپ  ...   gasoline  100000000   206         1383  18
# 5892       سالم و پلمپ  ...   gasoline   83000000   206         1380  21
# 5915       سالم و پلمپ  ...   gasoline   79800000   206         1383  18
# 5942       سالم و پلمپ  ...   gasoline   87000000   206         1380  21
# 5958       سالم و پلمپ  ...   gasoline   79500000   206         1382  19
# 6038       سالم و پلمپ  ...   gasoline   79000000   206         1380  21
# 6076       سالم و پلمپ  ...   gasoline   90000000   206         1380  21
# 6078       سالم و پلمپ  ...   gasoline  105000000   206         1382  19
# 6097       سالم و پلمپ  ...   gasoline   85000000   206         1381  20
# 6123       سالم و پلمپ  ...   gasoline   90000000   206         1383  18
# 6167       سالم و پلمپ  ...   gasoline   90000000   206         1381  20
# 6172       سالم و پلمپ  ...   gasoline  110000000   206         1386  15
# 6190       سالم و پلمپ  ...   gasoline   79000000   206         1382  19
# 6213       سالم و پلمپ  ...   gasoline   90000000   206         1384  17
# 6293        ضربه خورده  ...   gasoline   65000000   206         1380  21
# 6389       سالم و پلمپ  ...   gasoline   87000000   206         1383  18
# 6402       سالم و پلمپ  ...   gasoline   92000000   206         1381  20
# 6442       سالم و پلمپ  ...   gasoline   95000000   206         1384  17
# 6444       سالم و پلمپ  ...   gasoline   95000000   206         1383  18
# 6499       سالم و پلمپ  ...   gasoline   91000000   206         1383  18
# 6501       سالم و پلمپ  ...   gasoline  105000000   206         1383  18
# 6530       سالم و پلمپ  ...   gasoline   82000000   206         1382  19
# 6575       سالم و پلمپ  ...   gasoline   84000000   206         1380  21
# 6591       سالم و پلمپ  ...   gasoline   93000000   206         1383  18
# 6635       سالم و پلمپ  ...   gasoline   98000000   206         1381  20
# 6639       سالم و پلمپ  ...   gasoline   75000000   206         1381  20
# 6677       سالم و پلمپ  ...   gasoline   75000000   206         1381  20
# 6734       سالم و پلمپ  ...   gasoline  110000000   206         1386  15
# 6843       سالم و پلمپ  ...   gasoline   77000000   206         1382  19
# 6852       سالم و پلمپ  ...   gasoline   90000000   206         1384  17
# 6865        ضربه خورده  ...   gasoline  100000000   206         1385  16
# 6888       سالم و پلمپ  ...   gasoline   85000000   206         1382  19
# 6951       سالم و پلمپ  ...   gasoline   95000000   206         1384  17
# 6985       سالم و پلمپ  ...   gasoline   90000000   206         1382  19
# 7000       سالم و پلمپ  ...   gasoline   84000000   206         1382  19
# 7019       سالم و پلمپ  ...   gasoline   94000000   206         1384  17
# 7046       سالم و پلمپ  ...   gasoline   87500000   206         1380  21
# 7056       سالم و پلمپ  ...   gasoline   75000000   206         1380  21
# 7081       سالم و پلمپ  ...   gasoline   80000000   206         1383  18
# 7085       سالم و پلمپ  ...   gasoline   78000000   206         1382  19
# 7088       سالم و پلمپ  ...   gasoline   90000000   206         1383  18
# 7193       سالم و پلمپ  ...   gasoline   85000000   206         1382  19
# 7196       سالم و پلمپ  ...   gasoline   91000000   206         1384  17
# 7236       سالم و پلمپ  ...   gasoline   88500000   206         1383  18
# 7243       سالم و پلمپ  ...   gasoline  105000000   206         1383  18
# 7247       سالم و پلمپ  ...   gasoline  108300000   206         1387  14
# 7281       سالم و پلمپ  ...   gasoline   95000000   206         1386  15
# 7364       سالم و پلمپ  ...   gasoline   90000000   206         1382  19
# 7386       سالم و پلمپ  ...   gasoline  105000000   206         1383  18
# 7469       سالم و پلمپ  ...   gasoline  107000000   206         1384  17
# 7581       سالم و پلمپ  ...   gasoline   85000000   206         1380  21
# 7612       سالم و پلمپ  ...   gasoline   77000000   206         1381  20
# 7745       سالم و پلمپ  ...   gasoline   95000000   206         1380  21
# 7811       سالم و پلمپ  ...   gasoline   85000000   206         1382  19
# 7860       سالم و پلمپ  ...   gasoline   89000000   206         1383  18
# 7885       سالم و پلمپ  ...   gasoline   88000000   206         1384  17
# 7929       سالم و پلمپ  ...   gasoline   95000000   206         1384  17
# 8034       سالم و پلمپ  ...   gasoline   85000000   206         1381  20
# 8052       سالم و پلمپ  ...   gasoline   89500000   206         1382  19
# 8077       سالم و پلمپ  ...   gasoline   97000000   206         1381  20
# 8245       سالم و پلمپ  ...   gasoline  105000000   206         1386  15
# 8264       سالم و پلمپ  ...   gasoline   89000000   206         1383  18
# 8312       سالم و پلمپ  ...   gasoline  100000000   206         1385  16
# 8352       سالم و پلمپ  ...   gasoline  102000000   206         1384  17
# 8529       سالم و پلمپ  ...   gasoline  102000000   206         1386  15
# 8594       سالم و پلمپ  ...   gasoline   88000000   206         1382  19
# 8649       سالم و پلمپ  ...   gasoline   85000000   206         1382  19
# 8679       سالم و پلمپ  ...   gasoline   88000000   206         1383  18
# 8718       سالم و پلمپ  ...   gasoline   90000000   206         1382  19
# 8796       سالم و پلمپ  ...   gasoline   85000000   206         1380  21
# 8882       سالم و پلمپ  ...   gasoline   85000000   206         1383  18
# 8921       سالم و پلمپ  ...   gasoline   88000000   206         1383  18
# 8960       سالم و پلمپ  ...   gasoline  105000000   206         1386  15
# 9097       سالم و پلمپ  ...   gasoline   90000000   206         1383  18
# 9141       سالم و پلمپ  ...   gasoline   98000000   206         1383  18
# 9181       سالم و پلمپ  ...   gasoline   84000000   206         1383  18
# 9197       سالم و پلمپ  ...   gasoline   88000000   206         1381  20
# 9389       سالم و پلمپ  ...   gasoline  103000000   206         1384  17
# 9411       سالم و پلمپ  ...   gasoline  110000000   206         1385  16
#
#        color_levels  b_cond e_cond  c_cond if_automatic
# 57    graphite gray       2      A       A           no
# 85           silver       2      A       A           no
# 112          silver       2      A       A           no
# 303           other       1      A       A           no
# 318          silver      21      A       B           no
# 381           black       2      A       A          yes
# 382          silver       2      A       A           no
# 393           other       2      A       A           no
# 466          silver      11      C       A           no
# 487           black       1      A       A           no
# 491          silver       2      A       A           no
# 559           other      21      A       A           no
# 574          silver      21      A       B           no
# 579          silver       2      A       A           no
# 619           black       2      A       A           no
# 637           black       1      A       A           no
# 719           other       1      A       A           no
# 792          silver      21      A       A           no
# 843           black       1      A       A           no
# 869          silver      11      A       A           no
# 1119          other       1      A       A           no
# 1184          black       1      A       A           no
# 1194  graphite gray      21      A       A           no
# 1209          black      23      C       A           no
# 1347          black       2      A       A           no
# 1583          other       2      A       A           no
# 1601          other      13      C       A           no
# 1694          black       2      A       A           no
# 1799         silver       1      A       A           no
# 1863         silver      21      A       B           no
# 1870  graphite gray       2      A       A           no
# 1965          other      11      A       A           no
# 2329          other      21      A       A           no
# 2385          other      21      C       A           no
# 2550           gray      22      A       A           no
# 2554         silver      21      A       A           no
# 2662          black      13      A       A           no
# 2824         silver       1      A       A           no
# 2858         silver      21      A       B           no
# 2917         silver      21      A       A           no
# 2925         silver      21      A       A           no
# 2959          other       2      A       A           no
# 3038         silver       2      A       A           no
# 3272          other      21      A       A           no
# 3370         silver      21      A       A           no
# 3469         silver      21      A       A           no
# 3570         silver      21      A       B           no
# 3725         silver      21      A       A           no
# 3756          other      22      A       A           no
# 3762          other      13      A       A           no
# 3795         silver      21      A       A           no
# 3804          black       1      A       A           no
# 3806         silver       1      A       A           no
# 3889         silver      21      A       A           no
# 3965         silver      21      A       A           no
# 3982  graphite gray      11      A       A           no
# 4065          other      22      B       A           no
# 4087         silver       2      A       A           no
# 4402          black       5      A       A           no
# 4482         silver      21      A       A           no
# 4529         silver       1      A       A           no
# 4608          other       2      A       A           no
# 4708          other       2      A       A           no
# 4942         silver      22      A       B           no
# 4956          other      22      A       A           no
# 5101          other       1      A       B           no
# 5107         silver      22      A       A           no
# 5170          other       2      A       A           no
# 5273         silver       2      A       A           no
# 5325          other      21      A       A           no
# 5364         silver       2      A       A           no
# 5383          other      11      A       A           no
# 5431          other      22      A       A           no
# 5435          other      22      C       B           no
# 5446         silver       1      A       A           no
# 5459         silver       1      A       A           no
# 5476          other      22      A       A           no
# 5670          white      22      A       A           no
# 5682          other       2      A       A           no
# 5735         silver       2      A       A           no
# 5747         silver      21      A       A           no
# 5782          other      21      A       A           no
# 5813         silver      21      C       A           no
# 5818          other      22      A       A           no
# 5838           gray       2      A       A           no
# 5892          black       2      A       A           no
# 5915          other      22      A       A           no
# 5942          black       1      A       A           no
# 5958          other       2      A       A           no
# 6038          black      22      A       A           no
# 6076          other      22      A       A           no
# 6078         silver       2      A       A           no
# 6097          black       2      A       A           no
# 6123          other      21      A       A           no
# 6167          other      12      A       A           no
# 6172  graphite gray      22      A       A           no
# 6190          white      22      A       A           no
# 6213          other      21      A       A           no
# 6293          other      21      A       B           no
# 6389         silver      21      A       A           no
# 6402          other       2      A       A           no
# 6442         silver      21      A       A           no
# 6444         silver      12      A       A           no
# 6499          other       2      A       A           no
# 6501          other       1      A       A           no
# 6530          black      12      A       A           no
# 6575          other      21      A       A           no
# 6591          other       2      A       A           no
# 6635          other      21      A       A           no
# 6639          other       2      A       A           no
# 6677          black      21      A       A           no
# 6734          other      21      A       A           no
# 6843          other      12      A       A           no
# 6852          black      12      A       A           no
# 6865  graphite gray      22      A       B           no
# 6888          other       2      A       A           no
# 6951          other      22      A       A           no
# 6985          other       1      A       A           no
# 7000          other      21      A       A           no
# 7019          other      21      A       A           no
# 7046          white      21      A       A           no
# 7056          black      22      A       A           no
# 7081          other      21      A       A           no
# 7085          other      21      A       A           no
# 7088  graphite gray      12      A       A           no
# 7193          other       2      A       A           no
# 7196  graphite gray      12      A       A           no
# 7236         silver      12      A       A           no
# 7243  graphite gray      21      A       A           no
# 7247         silver       1      A       A           no
# 7281           gray      22      C       A           no
# 7364          other       1      A       A           no
# 7386         silver      15      A       A           no
# 7469         silver      21      A       A           no
# 7581          other      12      A       A           no
# 7612          black      22      A       A           no
# 7745          other      22      A       A           no
# 7811         silver      21      A       A           no
# 7860          other      11      A       A           no
# 7885         silver      22      A       A           no
# 7929          other       3      A       A           no
# 8034          other      21      A       A           no
# 8052  graphite gray      11      A       A           no
# 8077          other      21      A       A           no
# 8245  graphite gray       2      A       A           no
# 8264         silver      21      A       A           no
# 8312         silver      21      A       A           no
# 8352         silver       4      A       A           no
# 8529          other      21      A       A           no
# 8594         silver       1      A       A           no
# 8649         silver      21      A       A           no
# 8679         silver       2      A       A           no
# 8718         silver      21      A       A           no
# 8796          white      22      A       A           no
# 8882           gray      21      A       A           no
# 8921          other       2      A       A           no
# 8960  graphite gray      21      A       A           no
# 9097           gray       2      A       A           no
# 9141         silver      21      A       A           no
# 9181         silver       2      C       A           no
# 9197          white      21      A       A           no
# 9389         silver       2      A       A           no
# 9411         silver       1      A       A           no
#
# [163 rows x 22 columns]

# %%
#Check outliers for 207i
outlier_detector(df = data.loc[data['model'] == '207i', :])
#Note: check index 9196
# Out:
#         no       time     city                            brand
# 8        9 2022-03-26   Tehran        PEUGEOT 207i SD AUTOMATIC  \
# 10      11 2022-03-19   Tehran           PEUGEOT 207i AUTOMATIC
# 69      70 2022-03-27   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 89      90 2022-03-19   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 104    105 2022-03-12   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 284    285 2022-03-19   Tehran           PEUGEOT 207i AUTOMATIC
# 364    365 2022-03-05   Tehran           PEUGEOT 207i AUTOMATIC
# 366    367 2022-03-19   Tehran           PEUGEOT 207i AUTOMATIC
# 373    374 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 453    454 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 458    459 2022-03-19   Tehran           PEUGEOT 207i AUTOMATIC
# 624    625 2022-03-19   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 654    655 2022-03-05   Tehran           PEUGEOT 207i AUTOMATIC
# 679    680 2022-03-12   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 696    697 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 713    714 2022-03-30   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 746    747 2022-03-12   Tehran              PEUGEOT 207i MANUAL
# 850    851 2022-03-26   Tehran           PEUGEOT 207i AUTOMATIC
# 903    904 2022-03-26   Tehran           PEUGEOT 207i AUTOMATIC
# 917    918 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 1047  1048 2022-03-26   Tehran           PEUGEOT 207i AUTOMATIC
# 1065  1066 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 1103  1104 2022-03-26   Tehran           PEUGEOT 207i AUTOMATIC
# 1168  1169 2022-03-12   Tehran        PEUGEOT 207i SD AUTOMATIC
# 1431  1432 2022-03-05   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 1557  1558 2022-03-26   Tehran           PEUGEOT 207i AUTOMATIC
# 1611  1612 2022-03-19   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 1625  1626 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 1747  1748 2022-03-30   Tehran           PEUGEOT 207i AUTOMATIC
# 2196  2197 2022-03-19   Tehran           PEUGEOT 207i AUTOMATIC
# 2197  2198 2022-03-19   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 2484  2485 2022-03-26   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 2505  2506 2022-03-05   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 2685  2686 2022-03-19   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 2719  2720 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 2778  2779 2022-03-28   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 2812  2813 2022-03-12   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 2818  2819 2022-03-12   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 2862  2863 2022-03-19   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 3021  3022 2022-03-26   Tehran           PEUGEOT 207i AUTOMATIC
# 3165  3166 2022-03-26   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 3206  3207 2022-03-12   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 3283  3284 2022-03-12   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 3491  3492 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 3563  3564 2022-03-19   Tehran           PEUGEOT 207i AUTOMATIC
# 3601  3602 2022-03-26   Tehran           PEUGEOT 207i AUTOMATIC
# 3716  3717 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 3892  3893 2022-03-23   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 4012  4013 2022-03-19   Tehran           PEUGEOT 207i AUTOMATIC
# 4188  4189 2022-03-12   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 4198  4199 2022-03-19   Tehran           PEUGEOT 207i AUTOMATIC
# 4230  4231 2022-03-19   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 4276  4277 2022-03-29   Tehran           PEUGEOT 207i AUTOMATIC
# 4417  4418 2022-04-02   Tehran           PEUGEOT 207i AUTOMATIC
# 4426  4427 2022-03-12   Tehran           PEUGEOT 207i AUTOMATIC
# 4450  4451 2022-03-19   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 4651  4652 2022-03-12   Tehran  PEUGEOT 207i PANAROMA AUTOMATIC
# 5206  5207 2022-03-26  Mashhad           PEUGEOT 207i AUTOMATIC
# 5538  5539 2022-03-29  Mashhad           PEUGEOT 207i AUTOMATIC
# 5641  5642 2022-03-05  Mashhad  PEUGEOT 207i PANAROMA AUTOMATIC
# 5810  5811 2022-03-12  Mashhad           PEUGEOT 207i AUTOMATIC
# 5866  5867 2022-04-02  Mashhad  PEUGEOT 207i PANAROMA AUTOMATIC
# 5911  5912 2022-03-19  Mashhad  PEUGEOT 207i PANAROMA AUTOMATIC
# 6009  6010 2022-03-05  Mashhad  PEUGEOT 207i PANAROMA AUTOMATIC
# 6017  6018 2022-03-26  Mashhad           PEUGEOT 207i AUTOMATIC
# 6019  6020 2022-03-05  Mashhad           PEUGEOT 207i AUTOMATIC
# 6089  6090 2022-03-05  Mashhad  PEUGEOT 207i PANAROMA AUTOMATIC
# 6254  6255 2022-03-27  Mashhad           PEUGEOT 207i AUTOMATIC
# 6394  6395 2022-04-02  Mashhad  PEUGEOT 207i PANAROMA AUTOMATIC
# 6823  6824 2022-03-26  Isfahan  PEUGEOT 207i PANAROMA AUTOMATIC
# 6900  6901 2022-03-19  Isfahan           PEUGEOT 207i AUTOMATIC
# 6963  6964 2022-03-28  Isfahan           PEUGEOT 207i AUTOMATIC
# 7106  7107 2022-03-12  Isfahan           PEUGEOT 207i AUTOMATIC
# 7436  7437 2022-03-26  Isfahan  PEUGEOT 207i PANAROMA AUTOMATIC
# 7514  7515 2022-03-12  Isfahan  PEUGEOT 207i PANAROMA AUTOMATIC
# 7637  7638 2022-03-05  Isfahan  PEUGEOT 207i PANAROMA AUTOMATIC
# 7763  7764 2022-03-26  Isfahan  PEUGEOT 207i PANAROMA AUTOMATIC
# 8154  8155 2022-03-27  Isfahan  PEUGEOT 207i PANAROMA AUTOMATIC
# 8196  8197 2022-03-27  Isfahan           PEUGEOT 207i AUTOMATIC
# 8197  8198 2022-03-29  Isfahan  PEUGEOT 207i PANAROMA AUTOMATIC
# 8263  8264 2022-03-12   Shiraz  PEUGEOT 207i PANAROMA AUTOMATIC
# 8273  8274 2022-03-29   Shiraz  PEUGEOT 207i PANAROMA AUTOMATIC
# 8286  8287 2022-03-19   Shiraz           PEUGEOT 207i AUTOMATIC
# 8298  8299 2022-03-12   Shiraz           PEUGEOT 207i AUTOMATIC
# 8448  8449 2022-03-12   Shiraz  PEUGEOT 207i PANAROMA AUTOMATIC
# 8546  8547 2022-03-29   Shiraz           PEUGEOT 207i AUTOMATIC
# 8753  8754 2022-03-05   Shiraz           PEUGEOT 207i AUTOMATIC
# 8869  8870 2022-03-26   Shiraz  PEUGEOT 207i PANAROMA AUTOMATIC
# 8915  8916 2022-03-12   Shiraz  PEUGEOT 207i PANAROMA AUTOMATIC
# 8930  8931 2022-03-05   Shiraz  PEUGEOT 207i PANAROMA AUTOMATIC
# 9059  9060 2022-03-05   Shiraz  PEUGEOT 207i PANAROMA AUTOMATIC
# 9175  9176 2022-03-05   Shiraz  PEUGEOT 207i PANAROMA AUTOMATIC
# 9196  9197 2022-03-05   Shiraz     PEUGEOT 207i PANAROMA MANUAL
#
#       production_year      color      km       body_condition
# 8                1398    خاکستری       0    سالم و بی خط و خش  \
# 10               1400       مشکی    8000    سالم و بی خط و خش
# 69               1400       سفید    4000    سالم و بی خط و خش
# 89               1400       مشکی    5277    سالم و بی خط و خش
# 104              1400       سفید    8000    سالم و بی خط و خش
# 284              1400  سفید صدفی       0    سالم و بی خط و خش
# 364              1400       سفید   11000    سالم و بی خط و خش
# 366              1400       مشکی       0    سالم و بی خط و خش
# 373              1399       سفید       0    سالم و بی خط و خش
# 453              1389    نقره ای  180000    سالم و بی خط و خش
# 458              1400       مشکی       0    سالم و بی خط و خش
# 624              1400       مشکی   17000    سالم و بی خط و خش
# 654              1400       مشکی       0    سالم و بی خط و خش
# 679              1400       سفید    9000    سالم و بی خط و خش
# 696              1400       سفید       0    سالم و بی خط و خش
# 713              1400       سفید    4500    سالم و بی خط و خش
# 746              1396       سفید  130000             تمام رنگ
# 850              1398    خاکستری   24000    سالم و بی خط و خش
# 903              1400       سفید       0    سالم و بی خط و خش
# 917              1399       سفید   17000    سالم و بی خط و خش
# 1047             1400       سفید       0    سالم و بی خط و خش
# 1065             1400       مشکی   13000    سالم و بی خط و خش
# 1103             1400       مشکی       0    سالم و بی خط و خش
# 1168             1398       مشکی       0    سالم و بی خط و خش
# 1431             1400       سفید   13000    سالم و بی خط و خش
# 1557             1399       سفید    5000    سالم و بی خط و خش
# 1611             1400       سفید       0    سالم و بی خط و خش
# 1625             1400       مشکی   14000    سالم و بی خط و خش
# 1747             1390       سفید  182000  رنگ شدگی در ۳ ناحیه
# 2196             1399       سفید       0    سالم و بی خط و خش
# 2197             1400       سفید   14000    سالم و بی خط و خش
# 2484             1399       سفید    1200    سالم و بی خط و خش
# 2505             1400       سفید       0    سالم و بی خط و خش
# 2685             1400       مشکی   17000    سالم و بی خط و خش
# 2719             1400       مشکی   14000    سالم و بی خط و خش
# 2778             1400       سفید    6000    سالم و بی خط و خش
# 2812             1400  سفید صدفی    8000    سالم و بی خط و خش
# 2818             1400       سفید       0    سالم و بی خط و خش
# 2862             1400       سفید   11400  رنگ شدگی در ۱ ناحیه
# 3021             1391       مشکی  180000               دوررنگ
# 3165             1399    خاکستری       0    سالم و بی خط و خش
# 3206             1400       سفید       0    سالم و بی خط و خش
# 3283             1400       سفید      43    سالم و بی خط و خش
# 3491             1400       مشکی       0    سالم و بی خط و خش
# 3563             1390       مشکی  280000  رنگ شدگی در ۱ ناحیه
# 3601             1399       سفید       0    سالم و بی خط و خش
# 3716             1399       سفید     300    سالم و بی خط و خش
# 3892             1400    نقره ای       0    سالم و بی خط و خش
# 4012             1400    خاکستری    5000    سالم و بی خط و خش
# 4188             1400       سفید   15000    سالم و بی خط و خش
# 4198             1400       سفید       0    سالم و بی خط و خش
# 4230             1400       سفید       0    سالم و بی خط و خش
# 4276             1400       مشکی       0    سالم و بی خط و خش
# 4417             1400       مشکی   18000    سالم و بی خط و خش
# 4426             1390       سفید  178000               دوررنگ
# 4450             1400       سفید   12000    سالم و بی خط و خش
# 4651             1400       سفید    6000    سالم و بی خط و خش
# 5206             1399       سفید   11000    سالم و بی خط و خش
# 5538             1398       سفید      50    سالم و بی خط و خش
# 5641             1400       سفید   15000    سالم و بی خط و خش
# 5810             1390       سفید  140000  رنگ شدگی در ۲ ناحیه
# 5866             1400       سفید   18000    سالم و بی خط و خش
# 5911             1400       مشکی   21000    سالم و بی خط و خش
# 6009             1400       سفید    8700    سالم و بی خط و خش
# 6017             1399       سفید   12000    سالم و بی خط و خش
# 6019             1399       سفید       0    سالم و بی خط و خش
# 6089             1400       سفید    1000    سالم و بی خط و خش
# 6254             1398       سفید       0    سالم و بی خط و خش
# 6394             1400       سفید    7000    سالم و بی خط و خش
# 6823             1400  سفید صدفی      50    سالم و بی خط و خش
# 6900             1390  سفید صدفی  250000             تمام رنگ
# 6963             1400       مشکی   17000    سالم و بی خط و خش
# 7106             1399       سفید       0    سالم و بی خط و خش
# 7436             1400    نقره ای       0    سالم و بی خط و خش
# 7514             1399       سفید    5000    سالم و بی خط و خش
# 7637             1400       سفید    9000    سالم و بی خط و خش
# 7763             1400       سفید   18500    سالم و بی خط و خش
# 8154             1400       سفید   10000    سالم و بی خط و خش
# 8196             1400       سفید       0    سالم و بی خط و خش
# 8197             1400       مشکی    5270    سالم و بی خط و خش
# 8263             1399       سفید    6500    سالم و بی خط و خش
# 8273             1399       مشکی   21000    سالم و بی خط و خش
# 8286             1400       سفید       0    سالم و بی خط و خش
# 8298             1398       مشکی       1    سالم و بی خط و خش
# 8448             1400       سفید    5500    سالم و بی خط و خش
# 8546             1399       سفید    7000    سالم و بی خط و خش
# 8753             1400       سفید    7000    سالم و بی خط و خش
# 8869             1400       سفید   10000    سالم و بی خط و خش
# 8915             1400       سفید    7000    سالم و بی خط و خش
# 8930             1400       سفید       0    سالم و بی خط و خش
# 9059             1400       سفید       0    سالم و بی خط و خش
# 9175             1400       مشکی   12000    سالم و بی خط و خش
# 9196             1400       سفید       0    سالم و بی خط و خش
#
#      engine_condition chassis_condition  ...  fuel_type      price model
# 8                سالم       سالم و پلمپ  ...   gasoline  490000000  207i  \
# 10               سالم       سالم و پلمپ  ...   gasoline  500000000  207i
# 69               سالم       سالم و پلمپ  ...   gasoline  525000000  207i
# 89               سالم       سالم و پلمپ  ...   gasoline  535000000  207i
# 104              سالم       سالم و پلمپ  ...   gasoline  510000000  207i
# 284              سالم       سالم و پلمپ  ...   gasoline  490000000  207i
# 364              سالم       سالم و پلمپ  ...   gasoline  517000000  207i
# 366              سالم       سالم و پلمپ  ...   gasoline  520000000  207i
# 373              سالم       سالم و پلمپ  ...   gasoline  500000000  207i
# 453              سالم       سالم و پلمپ  ...   gasoline  248000000  207i
# 458              سالم       سالم و پلمپ  ...   gasoline  530000000  207i
# 624              سالم       سالم و پلمپ  ...   gasoline  525000000  207i
# 654              سالم       سالم و پلمپ  ...   gasoline  548000000  207i
# 679              سالم       سالم و پلمپ  ...   gasoline  515000000  207i
# 696              سالم       سالم و پلمپ  ...   gasoline  510000000  207i
# 713              سالم       سالم و پلمپ  ...   gasoline  515000000  207i
# 746              سالم       سالم و پلمپ  ...   gasoline  230000000  207i
# 850              سالم       سالم و پلمپ  ...   gasoline  500000000  207i
# 903              سالم       سالم و پلمپ  ...   gasoline  519000000  207i
# 917              سالم       سالم و پلمپ  ...   gasoline  485000000  207i
# 1047             سالم       سالم و پلمپ  ...   gasoline  525000000  207i
# 1065             سالم       سالم و پلمپ  ...   gasoline  495000000  207i
# 1103             سالم       سالم و پلمپ  ...   gasoline  525000000  207i
# 1168             سالم       سالم و پلمپ  ...   gasoline  490000000  207i
# 1431             سالم       سالم و پلمپ  ...   gasoline  533000000  207i
# 1557             سالم       سالم و پلمپ  ...   gasoline  500000000  207i
# 1611             سالم       سالم و پلمپ  ...   gasoline  535000000  207i
# 1625             سالم       سالم و پلمپ  ...   gasoline  512000000  207i
# 1747             سالم       سالم و پلمپ  ...   gasoline  216000000  207i
# 2196             سالم       سالم و پلمپ  ...   gasoline  495000000  207i
# 2197             سالم       سالم و پلمپ  ...   gasoline  525000000  207i
# 2484             سالم       سالم و پلمپ  ...   gasoline  494000000  207i
# 2505             سالم       سالم و پلمپ  ...   gasoline  535000000  207i
# 2685             سالم       سالم و پلمپ  ...   gasoline  520000000  207i
# 2719             سالم       سالم و پلمپ  ...   gasoline  500000000  207i
# 2778             سالم       سالم و پلمپ  ...   gasoline  500000000  207i
# 2812             سالم       سالم و پلمپ  ...   gasoline  517000000  207i
# 2818             سالم       سالم و پلمپ  ...   gasoline  540000000  207i
# 2862             سالم       سالم و پلمپ  ...   gasoline  485000000  207i
# 3021             سالم        ضربه خورده  ...   gasoline  230000000  207i
# 3165             سالم       سالم و پلمپ  ...   gasoline  525000000  207i
# 3206             سالم       سالم و پلمپ  ...   gasoline  555000000  207i
# 3283             سالم       سالم و پلمپ  ...   gasoline  552000000  207i
# 3491             سالم       سالم و پلمپ  ...   gasoline  541000000  207i
# 3563             سالم       سالم و پلمپ  ...   gasoline  247000000  207i
# 3601             سالم       سالم و پلمپ  ...   gasoline  490000000  207i
# 3716             سالم       سالم و پلمپ  ...   gasoline  485000000  207i
# 3892             سالم       سالم و پلمپ  ...   gasoline  535000000  207i
# 4012             سالم       سالم و پلمپ  ...   gasoline  530000000  207i
# 4188             سالم       سالم و پلمپ  ...   gasoline  514000000  207i
# 4198             سالم       سالم و پلمپ  ...   gasoline  512000000  207i
# 4230             سالم       سالم و پلمپ  ...   gasoline  544000000  207i
# 4276             سالم       سالم و پلمپ  ...   gasoline  520000000  207i
# 4417             سالم       سالم و پلمپ  ...   gasoline  505000000  207i
# 4426             سالم       سالم و پلمپ  ...   gasoline  220000000  207i
# 4450             سالم       سالم و پلمپ  ...   gasoline  516000000  207i
# 4651             سالم       سالم و پلمپ  ...   gasoline  508000000  207i
# 5206             سالم       سالم و پلمپ  ...   gasoline  485000000  207i
# 5538             سالم       سالم و پلمپ  ...   gasoline  485000000  207i
# 5641             سالم       سالم و پلمپ  ...   gasoline  498000000  207i
# 5810             سالم       سالم و پلمپ  ...   gasoline  245000000  207i
# 5866             سالم       سالم و پلمپ  ...   gasoline  540000000  207i
# 5911             سالم       سالم و پلمپ  ...   gasoline  505000000  207i
# 6009             سالم       سالم و پلمپ  ...   gasoline  530000000  207i
# 6017             سالم       سالم و پلمپ  ...   gasoline  494000000  207i
# 6019             سالم       سالم و پلمپ  ...   gasoline  498000000  207i
# 6089             سالم       سالم و پلمپ  ...   gasoline  535000000  207i
# 6254             سالم       سالم و پلمپ  ...   gasoline  490000000  207i
# 6394             سالم       سالم و پلمپ  ...   gasoline  525000000  207i
# 6823             سالم       سالم و پلمپ  ...   gasoline  500000000  207i
# 6900             سالم       سالم و پلمپ  ...   gasoline  218000000  207i
# 6963             سالم       سالم و پلمپ  ...   gasoline  505000000  207i
# 7106             سالم       سالم و پلمپ  ...   gasoline  510000000  207i
# 7436             سالم       سالم و پلمپ  ...   gasoline  542000000  207i
# 7514             سالم       سالم و پلمپ  ...   gasoline  500000000  207i
# 7637             سالم       سالم و پلمپ  ...   gasoline  530000000  207i
# 7763             سالم       سالم و پلمپ  ...   gasoline  505000000  207i
# 8154             سالم       سالم و پلمپ  ...   gasoline  485000000  207i
# 8196             سالم       سالم و پلمپ  ...   gasoline  510000000  207i
# 8197             سالم       سالم و پلمپ  ...   gasoline  530000000  207i
# 8263             سالم       سالم و پلمپ  ...   gasoline  485000000  207i
# 8273             سالم       سالم و پلمپ  ...   gasoline  495000000  207i
# 8286             سالم       سالم و پلمپ  ...   gasoline  530000000  207i
# 8298             سالم       سالم و پلمپ  ...   gasoline  505000000  207i
# 8448             سالم       سالم و پلمپ  ...   gasoline  520000000  207i
# 8546             سالم       سالم و پلمپ  ...   gasoline  512000000  207i
# 8753             سالم       سالم و پلمپ  ...   gasoline  510000000  207i
# 8869             سالم       سالم و پلمپ  ...   gasoline  530000000  207i
# 8915             سالم       سالم و پلمپ  ...   gasoline  510000000  207i
# 8930             سالم       سالم و پلمپ  ...   gasoline  541000000  207i
# 9059             سالم       سالم و پلمپ  ...   gasoline  539000000  207i
# 9175             سالم       سالم و پلمپ  ...   gasoline  535000000  207i
# 9196             سالم       سالم و پلمپ  ...   gasoline   10000000  207i
#
#       shamsy_year age  color_levels  b_cond e_cond  c_cond if_automatic
# 8            1398   3          gray       1      A       A          yes
# 10           1400   1         black       1      A       A          yes
# 69           1400   1         white       1      A       A          yes
# 89           1400   1         black       1      A       A          yes
# 104          1400   1         white       1      A       A          yes
# 284          1400   1         other       1      A       A          yes
# 364          1400   1         white       1      A       A          yes
# 366          1400   1         black       1      A       A          yes
# 373          1399   2         white       1      A       A           no
# 453          1389  12        silver       1      A       A          yes
# 458          1400   1         black       1      A       A          yes
# 624          1400   1         black       1      A       A          yes
# 654          1400   1         black       1      A       A          yes
# 679          1400   1         white       1      A       A          yes
# 696          1400   1         white       1      A       A          yes
# 713          1400   1         white       1      A       A          yes
# 746          1396   5         white      22      A       A           no
# 850          1398   3          gray       1      A       A          yes
# 903          1400   1         white       1      A       A          yes
# 917          1399   2         white       1      A       A          yes
# 1047         1400   1         white       1      A       A          yes
# 1065         1400   1         black       1      A       A          yes
# 1103         1400   1         black       1      A       A          yes
# 1168         1398   3         black       1      A       A          yes
# 1431         1400   1         white       1      A       A          yes
# 1557         1399   2         white       1      A       A          yes
# 1611         1400   1         white       1      A       A          yes
# 1625         1400   1         black       1      A       A          yes
# 1747         1390  11         white      13      A       A          yes
# 2196         1399   2         white       1      A       A          yes
# 2197         1400   1         white       1      A       A          yes
# 2484         1399   2         white       1      A       A          yes
# 2505         1400   1         white       1      A       A          yes
# 2685         1400   1         black       1      A       A          yes
# 2719         1400   1         black       1      A       A          yes
# 2778         1400   1         white       1      A       A          yes
# 2812         1400   1         other       1      A       A          yes
# 2818         1400   1         white       1      A       A          yes
# 2862         1400   1         white      11      A       A          yes
# 3021         1391  10         black      21      A       B          yes
# 3165         1399   2          gray       1      A       A          yes
# 3206         1400   1         white       1      A       A          yes
# 3283         1400   1         white       1      A       A          yes
# 3491         1400   1         black       1      A       A          yes
# 3563         1390  11         black      11      A       A          yes
# 3601         1399   2         white       1      A       A          yes
# 3716         1399   2         white       1      A       A          yes
# 3892         1400   1        silver       1      A       A          yes
# 4012         1400   1          gray       1      A       A          yes
# 4188         1400   1         white       1      A       A          yes
# 4198         1400   1         white       1      A       A          yes
# 4230         1400   1         white       1      A       A          yes
# 4276         1400   1         black       1      A       A          yes
# 4417         1400   1         black       1      A       A          yes
# 4426         1390  11         white      21      A       A          yes
# 4450         1400   1         white       1      A       A          yes
# 4651         1400   1         white       1      A       A          yes
# 5206         1399   2         white       1      A       A          yes
# 5538         1398   3         white       1      A       A          yes
# 5641         1400   1         white       1      A       A          yes
# 5810         1390  11         white      12      A       A          yes
# 5866         1400   1         white       1      A       A          yes
# 5911         1400   1         black       1      A       A          yes
# 6009         1400   1         white       1      A       A          yes
# 6017         1399   2         white       1      A       A          yes
# 6019         1399   2         white       1      A       A          yes
# 6089         1400   1         white       1      A       A          yes
# 6254         1398   3         white       1      A       A          yes
# 6394         1400   1         white       1      A       A          yes
# 6823         1400   1         other       1      A       A          yes
# 6900         1390  11         other      22      A       A          yes
# 6963         1400   1         black       1      A       A          yes
# 7106         1399   2         white       1      A       A          yes
# 7436         1400   1        silver       1      A       A          yes
# 7514         1399   2         white       1      A       A          yes
# 7637         1400   1         white       1      A       A          yes
# 7763         1400   1         white       1      A       A          yes
# 8154         1400   1         white       1      A       A          yes
# 8196         1400   1         white       1      A       A          yes
# 8197         1400   1         black       1      A       A          yes
# 8263         1399   2         white       1      A       A          yes
# 8273         1399   2         black       1      A       A          yes
# 8286         1400   1         white       1      A       A          yes
# 8298         1398   3         black       1      A       A          yes
# 8448         1400   1         white       1      A       A          yes
# 8546         1399   2         white       1      A       A          yes
# 8753         1400   1         white       1      A       A          yes
# 8869         1400   1         white       1      A       A          yes
# 8915         1400   1         white       1      A       A          yes
# 8930         1400   1         white       1      A       A          yes
# 9059         1400   1         white       1      A       A          yes
# 9175         1400   1         black       1      A       A          yes
# 9196         1400   1         white       1      A       A           no
#
# [93 rows x 22 columns]

# %%
#Check outliers for 405
outlier_detector(df = data.loc[data['model'] == '405', :])
#Note: check index 4550 and 5141
# Out:
#         no       time     city                brand  production_year    color
# 4550  4551 2022-03-19   Tehran  PEUGEOT 405 GLi GAS             1400  نقره ای  \
# 5141  5142 2022-03-05  Mashhad   PEUGEOT 405 GL GAS             1380    زرشکی
#
#           km     body_condition engine_condition chassis_condition  ...
# 4550       0  سالم و بی خط و خش             سالم       سالم و پلمپ  ...  \
# 5141  300000             دوررنگ             سالم       سالم و پلمپ  ...
#
#       fuel_type       price model  shamsy_year age  color_levels  b_cond
# 4550   gasoline  3000000000   405         1400   1        silver       1  \
# 5141   gasoline   650000000   405         1380  21         other      21
#
#      e_cond  c_cond if_automatic
# 4550      A       A          yes
# 5141      A       A           no
#
# [2 rows x 22 columns]

# %%
#Check outliers for PARS
outlier_detector(df = data.loc[data['model'] == 'PARS', :])
#Note: check index 6147
# Out:
#         no       time     city                       brand  production_year
# 2353  2354 2022-03-19   Tehran  PEUGEOT PARS AUTOMATIC TU5             1399  \
# 6147  6148 2022-03-05  Mashhad            PEUGEOT PARS ELX             1398
#
#      color    km     body_condition engine_condition chassis_condition  ...
# 2353  سفید  9000  سالم و بی خط و خش             سالم       سالم و پلمپ  ...  \
# 6147  سفید    57  سالم و بی خط و خش             سالم       سالم و پلمپ  ...
#
#       fuel_type       price model  shamsy_year age  color_levels  b_cond
# 2353   gasoline   425000000  PARS         1399   2         white       1  \
# 6147   gasoline  2580000000  PARS         1398   3         white       1
#
#      e_cond  c_cond if_automatic
# 2353      A       A          yes
# 6147      A       A           no
#
# [2 rows x 22 columns]

# %%
#Check outliers for ROA
outlier_detector(df = data.loc[data['model'] == 'ROA', :])
#Note: check index 989 and 4996
# Out:
#         no       time     city                   brand  production_year
# 989    990 2022-03-26   Tehran      PEUGEOT ROA HYBRID             1387  \
# 1925  1926 2022-03-27   Tehran      PEUGEOT ROA HYBRID             1386
# 2399  2400 2022-03-26   Tehran  PEUGEOT ROA SAL HYBRID             1390
# 2434  2435 2022-03-12   Tehran     PEUGEOT ROA SAL GAS             1389
# 2900  2901 2022-03-19   Tehran  PEUGEOT ROA SAL HYBRID             1389
# 3681  3682 2022-03-12   Tehran  PEUGEOT ROA SAL HYBRID             1390
# 4160  4161 2022-04-02   Tehran      PEUGEOT ROA HYBRID             1387
# 4996  4997 2022-03-12   Tehran      PEUGEOT ROA HYBRID             1387
# 5547  5548 2022-03-29  Mashhad  PEUGEOT ROA SAL HYBRID             1390
# 6488  6489 2022-03-27  Mashhad  PEUGEOT ROA SAL HYBRID             1390
# 6779  6780 2022-03-12  Isfahan  PEUGEOT ROA SAL HYBRID             1389
# 6874  6875 2022-03-05  Isfahan      PEUGEOT ROA HYBRID             1386
# 6983  6984 2022-03-28  Isfahan  PEUGEOT ROA SAL HYBRID             1389
# 9300  9301 2022-03-05   Shiraz      PEUGEOT ROA HYBRID             1387
#
#           color      km               body_condition engine_condition
# 989         زرد  500000                       دوررنگ    نیاز به تعمیر  \
# 1925        زرد  300000                 خط و خش جزیی             سالم
# 2399        زرد  500000            سالم و بی خط و خش             سالم
# 2434    نقره ای   34000            سالم و بی خط و خش             سالم
# 2900  نوک مدادی  280000            سالم و بی خط و خش             سالم
# 3681        زرد       0  صافکاری بی رنگ، در ۱۰ ناحیه             سالم
# 4160        زرد  350000          رنگ شدگی در ۱ ناحیه             سالم
# 4996  نوک مدادی  310002            سالم و بی خط و خش             سالم
# 5547    نقره ای  285000            سالم و بی خط و خش             سالم
# 6488    نقره ای  260000            سالم و بی خط و خش             سالم
# 6779    نقره ای  260000                 خط و خش جزیی             سالم
# 6874     نقرآبی  300000            سالم و بی خط و خش             سالم
# 6983    نقره ای  185000          رنگ شدگی در ۱ ناحیه             سالم
# 9300     نقرآبی  307000          رنگ شدگی در ۱ ناحیه             سالم
#
#      chassis_condition  ...  fuel_type       price model  shamsy_year age
# 989         ضربه خورده  ...     hybrid  1500000000   ROA         1387  14  \
# 1925       سالم و پلمپ  ...     hybrid    38000000   ROA         1386  15
# 2399       سالم و پلمپ  ...     hybrid   125000000   ROA         1390  11
# 2434       سالم و پلمپ  ...   gasoline   121000000   ROA         1389  12
# 2900       سالم و پلمپ  ...     hybrid   112500000   ROA         1389  12
# 3681       سالم و پلمپ  ...     hybrid   165000000   ROA         1390  11
# 4160       سالم و پلمپ  ...     hybrid   120000000   ROA         1387  14
# 4996       سالم و پلمپ  ...     hybrid   810000000   ROA         1387  14
# 5547       سالم و پلمپ  ...     hybrid   109500000   ROA         1390  11
# 6488       سالم و پلمپ  ...     hybrid   110000000   ROA         1390  11
# 6779       سالم و پلمپ  ...     hybrid   118000000   ROA         1389  12
# 6874       سالم و پلمپ  ...     hybrid   135000000   ROA         1386  15
# 6983       سالم و پلمپ  ...     hybrid   112000000   ROA         1389  12
# 9300       سالم و پلمپ  ...     hybrid   110000000   ROA         1387  14
#
#        color_levels  b_cond e_cond  c_cond if_automatic
# 989           other      21      C       B           no
# 1925          other       2      A       A           no
# 2399          other       1      A       A           no
# 2434         silver       1      A       A           no
# 2900  graphite gray       1      A       A           no
# 3681          other      10      A       A           no
# 4160          other      11      A       A           no
# 4996  graphite gray       1      A       A           no
# 5547         silver       1      A       A           no
# 6488         silver       1      A       A           no
# 6779         silver       2      A       A           no
# 6874          other       1      A       A           no
# 6983         silver      11      A       A           no
# 9300          other      11      A       A           no
#
# [14 rows x 22 columns]

# %%
#Type of outliers: procedural error
data.drop(index = [989, 1209, 4550, 4996, 5141, 6147, 9196], inplace = True)

#Boxplot for multiple groups
plt.boxplot([data.loc[data['model'] == '2008', 'price'], 
             data.loc[data['model'] == '206', 'price'],
             data.loc[data['model'] == '207i', 'price'],
             data.loc[data['model'] == '405', 'price'],
             data.loc[data['model'] == '407', 'price'],
             data.loc[data['model'] == 'PARS', 'price'],
             data.loc[data['model'] == 'RD', 'price'],
             data.loc[data['model'] == 'RDI', 'price'],
             data.loc[data['model'] == 'ROA', 'price'],
             data.loc[data['model'] == 'other', 'price']])
plt.title('Boxplot of Price vs. Models')
plt.xticks(ticks = list(range(1, 11)), 
           labels = ['2008', '206', '207i', '405', '407', 'PARS', 'RD', 'RDI', 'ROA', 'other'])
plt.xlabel('Model')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Data Understanding - Phase 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9505 entries, 0 to 9511
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   no                        9505 non-null   int64
#  1   time                      9505 non-null   datetime64[ns]
#  2   city                      9505 non-null   object
#  3   brand                     9505 non-null   object
#  4   production_year           9505 non-null   int64
#  5   color                     9505 non-null   object
#  6   km                        9505 non-null   int64
#  7   body_condition            9505 non-null   object
#  8   engine_condition          9505 non-null   object
#  9   chassis_condition         9505 non-null   object
#  10  insurance_time_to_expire  9505 non-null   int64
#  11  gearbox                   9505 non-null   object
#  12  fuel_type                 9505 non-null   object
#  13  price                     9505 non-null   int64
#  14  model                     9505 non-null   object
#  15  shamsy_year               9505 non-null   int64
#  16  age                       9505 non-null   int64
#  17  color_levels              9505 non-null   object
#  18  b_cond                    9505 non-null   int64
#  19  e_cond                    9505 non-null   object
#  20  c_cond                    9505 non-null   object
#  21  if_automatic              9505 non-null   object
# dtypes: datetime64[ns](1), int64(8), object(13)
# memory usage: 1.7+ MB

# %%
#Histogram of numeric variables
var_ind = [6, 10, 13, 16, 18]
plt.figure(figsize = (9, 6))
plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
for i in range(1, 6):
    plt.subplot(2, 3, i)
    plt.hist(x = data.iloc[: , var_ind[i - 1]], alpha = 0.4, color = 'red')
    plt.axvline(data.iloc[: , var_ind[i - 1]].mean(), color = 'gray', linewidth = 2, linestyle = '--')

    plt.title(data.columns[var_ind[i - 1]])

# %% [markdown]
# #### 5: Bivariate data analysis

# %%
#Correlation analysis
round(data.iloc[:, [13, 6, 10, 16, 18]].corr(method = 'pearson'), 2)
# Out:
#                           price    km  insurance_time_to_expire   age  b_cond
# price                      1.00 -0.60                      0.04 -0.74   -0.40
# km                        -0.60  1.00                     -0.07  0.73    0.38
# insurance_time_to_expire   0.04 -0.07                      1.00 -0.05   -0.04
# age                       -0.74  0.73                     -0.05  1.00    0.48
# b_cond                    -0.40  0.38                     -0.04  0.48    1.00

# %%
#Scatter plot
var_ind = [6, 10, 16, 18]
plt.figure(figsize = (9, 6))
plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
for i in range(1, 5):
    plt.subplot(2, 2, i)
    plt.scatter(x = data.iloc[: , var_ind[i - 1]], y = data['price'], alpha = 0.4, color = 'red')
    plt.title('Price vs. ' + data.columns[var_ind[i - 1]])

# %% [markdown]
# ## Build Linear Regression Model

# %%
#Split data into test and train
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size = .3, random_state = 123)
print(train.shape)
print(test.shape)
# Out:
# (6653, 22)
# (2852, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9505 entries, 0 to 9511
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   no                        9505 non-null   int64
#  1   time                      9505 non-null   datetime64[ns]
#  2   city                      9505 non-null   object
#  3   brand                     9505 non-null   object
#  4   production_year           9505 non-null   int64
#  5   color                     9505 non-null   object
#  6   km                        9505 non-null   int64
#  7   body_condition            9505 non-null   object
#  8   engine_condition          9505 non-null   object
#  9   chassis_condition         9505 non-null   object
#  10  insurance_time_to_expire  9505 non-null   int64
#  11  gearbox                   9505 non-null   object
#  12  fuel_type                 9505 non-null   object
#  13  price                     9505 non-null   int64
#  14  model                     9505 non-null   object
#  15  shamsy_year               9505 non-null   int64
#  16  age                       9505 non-null   int64
#  17  color_levels              9505 non-null   object
#  18  b_cond                    9505 non-null   int64
#  19  e_cond                    9505 non-null   object
#  20  c_cond                    9505 non-null   object
#  21  if_automatic              9505 non-null   object
# dtypes: datetime64[ns](1), int64(8), object(13)
# memory usage: 1.7+ MB

# %%
#Create dummy variables for categorical variables
dummy_vars = pd.get_dummies(train[['city',
                                   'fuel_type',
                                   'model',
                                   'color_levels', 
                                   'e_cond', 
                                   'c_cond', 
                                   'if_automatic']], dtype = int)
dummy_vars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6653 entries, 9085 to 3584
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city_Isfahan                6653 non-null   int32
#  1   city_Mashhad                6653 non-null   int32
#  2   city_Shiraz                 6653 non-null   int32
#  3   city_Tehran                 6653 non-null   int32
#  4   fuel_type_CNG               6653 non-null   int32
#  5   fuel_type_LPG               6653 non-null   int32
#  6   fuel_type_gasoline          6653 non-null   int32
#  7   fuel_type_hybrid            6653 non-null   int32
#  8   model_2008                  6653 non-null   int32
#  9   model_206                   6653 non-null   int32
#  10  model_207i                  6653 non-null   int32
#  11  model_405                   6653 non-null   int32
#  12  model_407                   6653 non-null   int32
#  13  model_PARS                  6653 non-null   int32
#  14  model_RD                    6653 non-null   int32
#  15  model_RDI                   6653 non-null   int32
#  16  model_ROA                   6653 non-null   int32
#  17  model_other                 6653 non-null   int32
#  18  color_levels_black          6653 non-null   int32
#  19  color_levels_graphite gray  6653 non-null   int32
#  20  color_levels_gray           6653 non-null   int32
#  21  color_levels_other          6653 non-null   int32
#  22  color_levels_silver         6653 non-null   int32
#  23  color_levels_white          6653 non-null   int32
#  24  e_cond_A                    6653 non-null   int32
#  25  e_cond_B                    6653 non-null   int32
#  26  e_cond_C                    6653 non-null   int32
#  27  c_cond_A                    6653 non-null   int32
#  28  c_cond_B                    6653 non-null   int32
#  29  c_cond_C                    6653 non-null   int32
#  30  if_automatic_no             6653 non-null   int32
#  31  if_automatic_yes            6653 non-null   int32
# dtypes: int32(32)
# memory usage: 883.6 KB

# %%
dummy_vars.head()
# Out:
#       city_Isfahan  city_Mashhad  city_Shiraz  city_Tehran  fuel_type_CNG
# 9085             0             0            1            0              1  \
# 3491             0             0            0            1              0
# 1091             0             0            0            1              0
# 701              0             0            0            1              0
# 3733             0             0            0            1              0
#
#       fuel_type_LPG  fuel_type_gasoline  fuel_type_hybrid  model_2008
# 9085              0                   0                 0           0  \
# 3491              0                   1                 0           0
# 1091              0                   1                 0           0
# 701               0                   1                 0           0
# 3733              0                   1                 0           0
#
#       model_206  ...  color_levels_silver  color_levels_white  e_cond_A
# 9085          0  ...                    1                   0         1  \
# 3491          0  ...                    0                   0         1
# 1091          0  ...                    0                   0         1
# 701           0  ...                    0                   0         1
# 3733          0  ...                    0                   1         1
#
#       e_cond_B  e_cond_C  c_cond_A  c_cond_B  c_cond_C  if_automatic_no
# 9085         0         0         1         0         0                1  \
# 3491         0         0         1         0         0                0
# 1091         0         0         1         0         0                1
# 701          0         0         1         0         0                1
# 3733         0         0         1         0         0                1
#
#       if_automatic_yes
# 9085                 0
# 3491                 1
# 1091                 0
# 701                  0
# 3733                 0
#
# [5 rows x 32 columns]

# %%
#Define base level for each categorical variable
dummy_vars.drop(columns = ['city_Tehran',
                           'fuel_type_gasoline',
                           'model_405',
                           'color_levels_white', 
                           'e_cond_A', 
                           'c_cond_A', 
                           'if_automatic_no' 
                           ], inplace = True)
dummy_vars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6653 entries, 9085 to 3584
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city_Isfahan                6653 non-null   int32
#  1   city_Mashhad                6653 non-null   int32
#  2   city_Shiraz                 6653 non-null   int32
#  3   fuel_type_CNG               6653 non-null   int32
#  4   fuel_type_LPG               6653 non-null   int32
#  5   fuel_type_hybrid            6653 non-null   int32
#  6   model_2008                  6653 non-null   int32
#  7   model_206                   6653 non-null   int32
#  8   model_207i                  6653 non-null   int32
#  9   model_407                   6653 non-null   int32
#  10  model_PARS                  6653 non-null   int32
#  11  model_RD                    6653 non-null   int32
#  12  model_RDI                   6653 non-null   int32
#  13  model_ROA                   6653 non-null   int32
#  14  model_other                 6653 non-null   int32
#  15  color_levels_black          6653 non-null   int32
#  16  color_levels_graphite gray  6653 non-null   int32
#  17  color_levels_gray           6653 non-null   int32
#  18  color_levels_other          6653 non-null   int32
#  19  color_levels_silver         6653 non-null   int32
#  20  e_cond_B                    6653 non-null   int32
#  21  e_cond_C                    6653 non-null   int32
#  22  c_cond_B                    6653 non-null   int32
#  23  c_cond_C                    6653 non-null   int32
#  24  if_automatic_yes            6653 non-null   int32
# dtypes: int32(25)
# memory usage: 701.7 KB

# %%
#Define feature matrix 
X_ = train[['km', 'insurance_time_to_expire', 'age', 'b_cond']]
X_train = pd.concat([X_, dummy_vars], axis = 1)
X_train = sm.add_constant(X_train) #add constant
X_train.head()
# Out:
#       const      km  insurance_time_to_expire  age  b_cond  city_Isfahan
# 9085    1.0       0                        11   15      22             0  \
# 3491    1.0       0                         9    1       1             0
# 1091    1.0   33000                         7    2       1             0
# 701     1.0  272002                         7   19      21             0
# 3733    1.0       0                         8    1       1             0
#
#       city_Mashhad  city_Shiraz  fuel_type_CNG  fuel_type_LPG  ...
# 9085             0            1              1              0  ...  \
# 3491             0            0              0              0  ...
# 1091             0            0              0              0  ...
# 701              0            0              0              0  ...
# 3733             0            0              0              0  ...
#
#       color_levels_black  color_levels_graphite gray  color_levels_gray
# 9085                   0                           0                  0  \
# 3491                   1                           0                  0
# 1091                   0                           0                  0
# 701                    1                           0                  0
# 3733                   0                           0                  0
#
#       color_levels_other  color_levels_silver  e_cond_B  e_cond_C  c_cond_B
# 9085                   0                    1         0         0         0  \
# 3491                   0                    0         0         0         0
# 1091                   1                    0         0         0         0
# 701                    0                    0         0         0         0
# 3733                   0                    0         0         0         0
#
#       c_cond_C  if_automatic_yes
# 9085         0                 0
# 3491         0                 1
# 1091         0                 0
# 701          0                 0
# 3733         0                 0
#
# [5 rows x 30 columns]

# %%
#Define response matrix
y_train = train['price']
y_train
# Out:
# 9085    110000000
# 3491    541000000
# 1091    253000000
# 701      75000000
# 3733    278000000
#           ...
# 7388    240000000
# 7769     72000000
# 5223    212000000
# 1348     76000000
# 3584    235000000
# Name: price, Length: 6653, dtype: int64

# %%
#Linear regression - model 1
model_1 = sm.OLS(y_train, X_train).fit()
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     2144.
# Date:                Wed, 09 Aug 2023   Prob (F-statistic):               0.00
# Time:                        04:11:42   Log-Likelihood:            -1.2446e+05
# No. Observations:                6653   AIC:                         2.490e+05
# Df Residuals:                    6623   BIC:                         2.492e+05
# Df Model:                          29
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                       2.696e+08   1.66e+06    162.063      0.000    2.66e+08    2.73e+08
# km                           -77.6479      5.330    -14.569      0.000     -88.095     -67.200
# insurance_time_to_expire    4.935e+05   1.19e+05      4.143      0.000     2.6e+05    7.27e+05
# age                         -8.75e+06   1.25e+05    -70.159      0.000   -8.99e+06   -8.51e+06
# b_cond                     -8.782e+05   7.46e+04    -11.767      0.000   -1.02e+06   -7.32e+05
# city_Isfahan                4.199e+06   1.16e+06      3.623      0.000    1.93e+06    6.47e+06
# city_Mashhad                1.369e+06   1.12e+06      1.224      0.221   -8.24e+05    3.56e+06
# city_Shiraz                 2.259e+06    1.2e+06      1.879      0.060   -9.72e+04    4.61e+06
# fuel_type_CNG              -5.214e+06   1.46e+06     -3.571      0.000   -8.08e+06   -2.35e+06
# fuel_type_LPG               6.455e+06   3.42e+06      1.890      0.059   -2.41e+05    1.32e+07
# fuel_type_hybrid            8.778e+05      2e+06      0.440      0.660   -3.04e+06    4.79e+06
# model_2008                  6.324e+08   7.13e+06     88.673      0.000    6.18e+08    6.46e+08
# model_206                   1.375e+07   1.26e+06     10.903      0.000    1.13e+07    1.62e+07
# model_207i                  9.371e+07   1.97e+06     47.469      0.000    8.98e+07    9.76e+07
# model_407                   2.447e+08   9.56e+06     25.608      0.000    2.26e+08    2.63e+08
# model_PARS                  2.858e+07    1.4e+06     20.356      0.000    2.58e+07    3.13e+07
# model_RD                   -3.524e+07   2.58e+06    -13.648      0.000   -4.03e+07   -3.02e+07
# model_RDI                  -3.663e+07    5.3e+06     -6.916      0.000    -4.7e+07   -2.62e+07
# model_ROA                  -4.431e+07   2.99e+06    -14.799      0.000   -5.02e+07   -3.84e+07
# model_other                 2.715e+08   9.43e+06     28.789      0.000    2.53e+08     2.9e+08
# color_levels_black          -5.09e+06   1.84e+06     -2.767      0.006    -8.7e+06   -1.48e+06
# color_levels_graphite gray -1.184e+07   2.02e+06     -5.872      0.000   -1.58e+07   -7.89e+06
# color_levels_gray          -1.188e+07   1.43e+06     -8.313      0.000   -1.47e+07   -9.08e+06
# color_levels_other         -6.922e+06   1.38e+06     -5.007      0.000   -9.63e+06   -4.21e+06
# color_levels_silver         -1.32e+07   1.53e+06     -8.646      0.000   -1.62e+07   -1.02e+07
# e_cond_B                     3.37e+06    5.7e+06      0.591      0.554   -7.81e+06    1.45e+07
# e_cond_C                   -1.837e+07   4.97e+06     -3.697      0.000   -2.81e+07   -8.63e+06
# c_cond_B                   -6.947e+06   3.71e+06     -1.871      0.061   -1.42e+07    3.32e+05
# c_cond_C                   -2.776e+07   1.08e+07     -2.563      0.010    -4.9e+07   -6.53e+06
# if_automatic_yes            7.948e+07   2.01e+06     39.567      0.000    7.55e+07    8.34e+07
# ==============================================================================
# Omnibus:                     9456.654   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15238333.145
# Skew:                           7.716   Prob(JB):                         0.00
# Kurtosis:                     236.950   Cond. No.                     4.51e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.51e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Function to plot histogram of residuals
def hist_residuals(model, bins = 50):
    #Calculate density
    from scipy import stats
    density = stats.gaussian_kde(model.resid)
    xp = np.linspace(model.resid.min(), model.resid.max(), 100)
    yp = density.pdf(xp)

    #Histogram
    plt.hist(model.resid, bins = bins, 
             color = 'red', alpha = 0.7, density = True)
    plt.axvline(model.resid.mean(), color = 'gray', 
                linewidth = 2, linestyle = '--', label = "Average")
    plt.title('Histogram of Residuals')
    plt.xlabel('Residuals')
    plt.ylabel('Density')
    plt.plot(xp, yp, color = 'gray', linewidth = 2)
    plt.legend()
    
    return plt.show()

# %%
#Histogram of residuals - model 1
hist_residuals(model_1)

# %%
#QQ-plot - model 1
sm.qqplot(model_1.resid, line = 's')
plt.show()

# %%
#Function to plot residuals vs. fitted values
def residuals_fittedvalues_plot(model):
    #Implement Lowess algorithm
    lowess_res = sm.nonparametric.lowess(model.resid, model.fittedvalues)

    #Scatter plot: residuals vs. fitted values
    plt.scatter(x = model.fittedvalues, y = model.resid, 
                color = 'red', alpha = .6, label = 'data')
    plt.title('Residuals vs. Fitted values')
    plt.xlabel('Fitted Values', fontsize = 12)
    plt.ylabel('Residuals', fontsize = 12)
    plt.grid()

    #Add LOWESS line
    plt.plot(lowess_res[:, 0], lowess_res[:, 1], 'gray', 
             alpha = 0.8, linewidth = 2, label = 'LOWESS')
    plt.legend()

    #Top three observations with greates absolute value of the residual
    top3 = abs(model.resid).sort_values(ascending = False)[:3]
    for i in top3.index:
        plt.annotate(i, xy = (model.fittedvalues[i], model.resid[i]), color = 'blue')
    
    return plt.show()

# %%
#Scatter plot of residuals vs. fitted values - model 1
residuals_fittedvalues_plot(model_1)

# %%
train.iloc[[2993, 5913, 6098], :]
# Out:
#         no       time     city                   brand  production_year
# 7012  7013 2022-03-19  Isfahan     PEUGEOT 405 GLX GAS             1393  \
# 1864  1865 2022-03-05   Tehran  PEUGEOT 207i AUTOMATIC             1398
# 6392  6393 2022-03-29  Mashhad     PEUGEOT 207i MANUAL             1397
#
#        color      km     body_condition engine_condition chassis_condition
# 7012  دلفینی  150000  سالم و بی خط و خش             سالم       سالم و پلمپ  \
# 1864    سفید   25000  سالم و بی خط و خش             سالم       سالم و پلمپ
# 6392    مشکی   85000  سالم و بی خط و خش             سالم       سالم و پلمپ
#
#       ...  fuel_type      price model  shamsy_year age  color_levels  b_cond
# 7012  ...   gasoline  173500000   405         1393   8         other       1  \
# 1864  ...   gasoline  450000000  207i         1398   3         white       1
# 6392  ...   gasoline  290000000  207i         1397   4         black       1
#
#      e_cond  c_cond if_automatic
# 7012      A       A           no
# 1864      A       A          yes
# 6392      A       A           no
#
# [3 rows x 22 columns]

# %%
#Function to check Cook's distance
def influencer_detector(model, thershold = 1):
    
    #create instance of influence
    influence = model.get_influence()

    #Obtain Cook's distance for each observation
    cooks = influence.cooks_distance

    #Check observations w/ Cook's distance greater than thershold
    return np.where(cooks[0] > 1)

# %%
#Check Cook's ditance - model 1
influencer_detector(model_1)
# Out:
# (array([5310, 5392, 5776], dtype=int64),)

# %%
train.iloc[[5310, 5392, 5776], :]
# Out:
#         no       time     city           brand  production_year      color
# 6098  6099 2022-03-19  Mashhad  PEUGEOT 508 GT             2017    نقره ای  \
# 5913  5914 2022-03-27  Mashhad  PEUGEOT 508 GT             2016  سفید صدفی
# 2993  2994 2022-03-05   Tehran  PEUGEOT 508 GT             2017  سفید صدفی
#
#          km     body_condition engine_condition chassis_condition  ...
# 6098  86000  سالم و بی خط و خش             سالم       سالم و پلمپ  ...  \
# 5913  89000  سالم و بی خط و خش             سالم       سالم و پلمپ  ...
# 2993   4000  سالم و بی خط و خش             سالم       سالم و پلمپ  ...
#
#       fuel_type       price  model  shamsy_year age  color_levels  b_cond
# 6098   gasoline  1140000000  other         1396   5        silver       1  \
# 5913   gasoline  1480000000  other         1395   6         other       1
# 2993   gasoline  1520000000  other         1396   5         other       1
#
#      e_cond  c_cond if_automatic
# 6098      A       A          yes
# 5913      A       A          yes
# 2993      A       A          yes
#
# [3 rows x 22 columns]

# %%
#Function to check multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):
    #Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X, i) for i in range(X.shape[1])]
    return(vif)

# %%
#Check multicollinearity for numeric variables
calc_vif(X_train[['km', 'insurance_time_to_expire', 'age', 'b_cond']])
#Note: If VIF > 10 then multicollinearity is high
# Out:
#                   variables       VIF
# 0                        km  4.525167
# 1  insurance_time_to_expire  2.048922
# 2                       age  6.080495
# 3                    b_cond  1.976046

# %%
#Box-Cox transformation
from sklearn.preprocessing import PowerTransformer
boxcox = PowerTransformer(method = 'box-cox')
boxcox.fit(y_train.values.reshape(-1, 1))
boxcox.lambdas_
# Out:
# array([0.492546])

# %%
trans_y_train = boxcox.fit_transform(y_train.values.reshape(-1, 1))
plt.hist(trans_y_train, color = 'red', alpha = 0.5, bins = 50)
plt.show()

# %%
#Linear regression - model 2
model_2 = sm.OLS(trans_y_train, X_train).fit()
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     3714.
# Date:                Wed, 09 Aug 2023   Prob (F-statistic):               0.00
# Time:                        04:11:48   Log-Likelihood:                 35.859
# No. Observations:                6653   AIC:                            -11.72
# Df Residuals:                    6623   BIC:                             192.4
# Df Model:                          29
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.6697      0.012     53.914      0.000       0.645       0.694
# km                         -6.494e-07   3.98e-08    -16.320      0.000   -7.27e-07   -5.71e-07
# insurance_time_to_expire       0.0032      0.001      3.564      0.000       0.001       0.005
# age                           -0.0961      0.001   -103.164      0.000      -0.098      -0.094
# b_cond                        -0.0101      0.001    -18.122      0.000      -0.011      -0.009
# city_Isfahan                   0.0430      0.009      4.974      0.000       0.026       0.060
# city_Mashhad                  -0.0013      0.008     -0.155      0.876      -0.018       0.015
# city_Shiraz                    0.0209      0.009      2.327      0.020       0.003       0.038
# fuel_type_CNG                 -0.0411      0.011     -3.772      0.000      -0.062      -0.020
# fuel_type_LPG                 -0.0071      0.026     -0.278      0.781      -0.057       0.043
# fuel_type_hybrid               0.0318      0.015      2.134      0.033       0.003       0.061
# model_2008                     3.7437      0.053     70.301      0.000       3.639       3.848
# model_206                      0.1808      0.009     19.198      0.000       0.162       0.199
# model_207i                     0.7851      0.015     53.261      0.000       0.756       0.814
# model_407                      2.1875      0.071     30.660      0.000       2.048       2.327
# model_PARS                     0.3049      0.010     29.079      0.000       0.284       0.325
# model_RD                      -0.7178      0.019    -37.229      0.000      -0.756      -0.680
# model_RDI                     -0.6594      0.040    -16.671      0.000      -0.737      -0.582
# model_ROA                     -0.6818      0.022    -30.495      0.000      -0.726      -0.638
# model_other                    1.3107      0.070     18.615      0.000       1.173       1.449
# color_levels_black            -0.0591      0.014     -4.306      0.000      -0.086      -0.032
# color_levels_graphite gray    -0.0983      0.015     -6.527      0.000      -0.128      -0.069
# color_levels_gray             -0.0851      0.011     -7.970      0.000      -0.106      -0.064
# color_levels_other            -0.0881      0.010     -8.539      0.000      -0.108      -0.068
# color_levels_silver           -0.1076      0.011     -9.436      0.000      -0.130      -0.085
# e_cond_B                      -0.0137      0.043     -0.322      0.747      -0.097       0.070
# e_cond_C                      -0.2167      0.037     -5.842      0.000      -0.289      -0.144
# c_cond_B                      -0.1175      0.028     -4.238      0.000      -0.172      -0.063
# c_cond_C                      -0.3221      0.081     -3.984      0.000      -0.481      -0.164
# if_automatic_yes               0.6479      0.015     43.197      0.000       0.618       0.677
# ==============================================================================
# Omnibus:                     5633.146   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1174322.614
# Skew:                           3.266   Prob(JB):                         0.00
# Kurtosis:                      67.758   Cond. No.                     4.51e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.51e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Histogram of residuals - model 2
hist_residuals(model_2)

# %%
#QQ-plot - model 2
sm.qqplot(model_2.resid, line = 's')
plt.show()

# %%
#Scatter plot of residuals vs. fitted values - model 2
residuals_fittedvalues_plot(model_2)

# %%
#Check Cook's ditance - model 2
influencer_detector(model_2)
# Out:
# (array([5392, 5776], dtype=int64),)

# %%
train.iloc[[5392, 5776], :]
# Out:
#         no       time     city           brand  production_year      color
# 5913  5914 2022-03-27  Mashhad  PEUGEOT 508 GT             2016  سفید صدفی  \
# 2993  2994 2022-03-05   Tehran  PEUGEOT 508 GT             2017  سفید صدفی
#
#          km     body_condition engine_condition chassis_condition  ...
# 5913  89000  سالم و بی خط و خش             سالم       سالم و پلمپ  ...  \
# 2993   4000  سالم و بی خط و خش             سالم       سالم و پلمپ  ...
#
#       fuel_type       price  model  shamsy_year age  color_levels  b_cond
# 5913   gasoline  1480000000  other         1395   6         other       1  \
# 2993   gasoline  1520000000  other         1396   5         other       1
#
#      e_cond  c_cond if_automatic
# 5913      A       A          yes
# 2993      A       A          yes
#
# [2 rows x 22 columns]

# %%
#Note: Remove observations (be cautious!)
X_train.drop(index = [2993, 5913, 5392, 6098, 5776], inplace = True)
y_train.drop(index = [2993, 5913, 5392, 6098, 5776], inplace = True)
trans_y_train = PowerTransformer(method = 'box-cox').fit_transform(y_train.values.reshape(-1, 1))

# %%
#Linear regression - model 3
model_3 = sm.OLS(trans_y_train, X_train).fit()
model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     4590.
# Date:                Wed, 09 Aug 2023   Prob (F-statistic):               0.00
# Time:                        04:11:53   Log-Likelihood:                 704.64
# No. Observations:                6648   AIC:                            -1349.
# Df Residuals:                    6618   BIC:                            -1145.
# Df Model:                          29
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.6703      0.011     59.675      0.000       0.648       0.692
# km                         -6.654e-07    3.6e-08    -18.490      0.000   -7.36e-07   -5.95e-07
# insurance_time_to_expire       0.0026      0.001      3.214      0.001       0.001       0.004
# age                           -0.0949      0.001   -112.666      0.000      -0.097      -0.093
# b_cond                        -0.0101      0.001    -20.062      0.000      -0.011      -0.009
# city_Isfahan                   0.0480      0.008      6.131      0.000       0.033       0.063
# city_Mashhad                  -0.0116      0.008     -1.530      0.126      -0.026       0.003
# city_Shiraz                    0.0217      0.008      2.677      0.007       0.006       0.038
# fuel_type_CNG                 -0.0401      0.010     -4.067      0.000      -0.059      -0.021
# fuel_type_LPG                 -0.0090      0.023     -0.392      0.695      -0.054       0.036
# fuel_type_hybrid               0.0249      0.013      1.848      0.065      -0.002       0.051
# model_2008                     4.0214      0.048     83.469      0.000       3.927       4.116
# model_206                      0.1816      0.009     21.323      0.000       0.165       0.198
# model_207i                     0.8378      0.013     62.767      0.000       0.812       0.864
# model_407                      2.2817      0.065     35.360      0.000       2.155       2.408
# model_PARS                     0.3125      0.009     32.956      0.000       0.294       0.331
# model_RD                      -0.6976      0.017    -40.002      0.000      -0.732      -0.663
# model_RDI                     -0.6491      0.036    -18.147      0.000      -0.719      -0.579
# model_ROA                     -0.6678      0.020    -33.031      0.000      -0.707      -0.628
# model_other                   -0.1906      0.073     -2.593      0.010      -0.335      -0.047
# color_levels_black            -0.0547      0.012     -4.403      0.000      -0.079      -0.030
# color_levels_graphite gray    -0.1041      0.014     -7.643      0.000      -0.131      -0.077
# color_levels_gray             -0.0923      0.010     -9.560      0.000      -0.111      -0.073
# color_levels_other            -0.1004      0.009    -10.752      0.000      -0.119      -0.082
# color_levels_silver           -0.1214      0.010    -11.769      0.000      -0.142      -0.101
# e_cond_B                      -0.0200      0.038     -0.520      0.603      -0.095       0.055
# e_cond_C                      -0.1430      0.034     -4.257      0.000      -0.209      -0.077
# c_cond_B                      -0.1222      0.025     -4.875      0.000      -0.171      -0.073
# c_cond_C                      -0.3281      0.073     -4.487      0.000      -0.471      -0.185
# if_automatic_yes               0.6050      0.014     44.381      0.000       0.578       0.632
# ==============================================================================
# Omnibus:                     1357.663   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7860.251
# Skew:                           0.853   Prob(JB):                         0.00
# Kurtosis:                       8.046   Cond. No.                     4.54e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.54e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Histogram of residuals - model 3
hist_residuals(model_3)

# %%
#QQ-plot - model 3
sm.qqplot(model_3.resid, line = 's')
plt.show()

# %%
#Scatter plot of residuals vs. fitted values - model 3
residuals_fittedvalues_plot(model_3)

# %%
#Check Cook's ditance - model 3
influencer_detector(model_3)
# Out:
# (array([], dtype=int64),)

# %%
#Remove non-significant variables from regression model
X_train.drop(columns = ['city_Mashhad', 
                        'fuel_type_LPG', 
                        'fuel_type_hybrid', 
                        'e_cond_B'], inplace = True)

# %%
#Linear regression - model 4
model_4 = sm.OLS(trans_y_train, X_train).fit()
model_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     5322.
# Date:                Wed, 09 Aug 2023   Prob (F-statistic):               0.00
# Time:                        04:11:58   Log-Likelihood:                 701.71
# No. Observations:                6648   AIC:                            -1351.
# Df Residuals:                    6622   BIC:                            -1175.
# Df Model:                          25
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.6672      0.011     60.216      0.000       0.646       0.689
# km                         -6.627e-07   3.59e-08    -18.481      0.000   -7.33e-07   -5.92e-07
# insurance_time_to_expire       0.0026      0.001      3.189      0.001       0.001       0.004
# age                           -0.0950      0.001   -113.203      0.000      -0.097      -0.093
# b_cond                        -0.0101      0.001    -20.107      0.000      -0.011      -0.009
# city_Isfahan                   0.0512      0.008      6.778      0.000       0.036       0.066
# city_Shiraz                    0.0245      0.008      3.109      0.002       0.009       0.040
# fuel_type_CNG                 -0.0411      0.010     -4.248      0.000      -0.060      -0.022
# model_2008                     4.0226      0.048     83.496      0.000       3.928       4.117
# model_206                      0.1820      0.008     21.515      0.000       0.165       0.199
# model_207i                     0.8387      0.013     62.925      0.000       0.813       0.865
# model_407                      2.2810      0.065     35.355      0.000       2.154       2.407
# model_PARS                     0.3172      0.009     34.744      0.000       0.299       0.335
# model_RD                      -0.7006      0.017    -41.033      0.000      -0.734      -0.667
# model_RDI                     -0.6480      0.036    -18.158      0.000      -0.718      -0.578
# model_ROA                     -0.6492      0.017    -37.519      0.000      -0.683      -0.615
# model_other                   -0.1894      0.073     -2.578      0.010      -0.333      -0.045
# color_levels_black            -0.0553      0.012     -4.457      0.000      -0.080      -0.031
# color_levels_graphite gray    -0.1037      0.014     -7.617      0.000      -0.130      -0.077
# color_levels_gray             -0.0912      0.010     -9.472      0.000      -0.110      -0.072
# color_levels_other            -0.1002      0.009    -10.740      0.000      -0.118      -0.082
# color_levels_silver           -0.1212      0.010    -11.753      0.000      -0.141      -0.101
# e_cond_C                      -0.1426      0.034     -4.246      0.000      -0.208      -0.077
# c_cond_B                      -0.1238      0.025     -4.944      0.000      -0.173      -0.075
# c_cond_C                      -0.3251      0.073     -4.447      0.000      -0.468      -0.182
# if_automatic_yes               0.6054      0.014     44.527      0.000       0.579       0.632
# ==============================================================================
# Omnibus:                     1341.687   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7677.780
# Skew:                           0.845   Prob(JB):                         0.00
# Kurtosis:                       7.986   Cond. No.                     4.54e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.54e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#QQ-plot - model 4
sm.qqplot(model_4.resid, line = 's')
plt.show()

# %%
#Scatter plot of residuals vs. fitted values - model 4
residuals_fittedvalues_plot(model_4)

# %%
#Check Cook's ditance - model 4
influencer_detector(model_4)
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ## Model Evaluation

# %%
#Create dummy variables for categorical variables in test
dummy_vars = pd.get_dummies(test[['city',
                                  'fuel_type',
                                  'model',
                                  'color_levels', 
                                  'e_cond', 
                                  'c_cond', 
                                  'if_automatic']], dtype = int)
dummy_vars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2852 entries, 2847 to 5572
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city_Isfahan                2852 non-null   int32
#  1   city_Mashhad                2852 non-null   int32
#  2   city_Shiraz                 2852 non-null   int32
#  3   city_Tehran                 2852 non-null   int32
#  4   fuel_type_CNG               2852 non-null   int32
#  5   fuel_type_LPG               2852 non-null   int32
#  6   fuel_type_gasoline          2852 non-null   int32
#  7   fuel_type_hybrid            2852 non-null   int32
#  8   model_2008                  2852 non-null   int32
#  9   model_206                   2852 non-null   int32
#  10  model_207i                  2852 non-null   int32
#  11  model_405                   2852 non-null   int32
#  12  model_407                   2852 non-null   int32
#  13  model_PARS                  2852 non-null   int32
#  14  model_RD                    2852 non-null   int32
#  15  model_RDI                   2852 non-null   int32
#  16  model_ROA                   2852 non-null   int32
#  17  model_other                 2852 non-null   int32
#  18  color_levels_black          2852 non-null   int32
#  19  color_levels_graphite gray  2852 non-null   int32
#  20  color_levels_gray           2852 non-null   int32
#  21  color_levels_other          2852 non-null   int32
#  22  color_levels_silver         2852 non-null   int32
#  23  color_levels_white          2852 non-null   int32
#  24  e_cond_A                    2852 non-null   int32
#  25  e_cond_B                    2852 non-null   int32
#  26  e_cond_C                    2852 non-null   int32
#  27  c_cond_A                    2852 non-null   int32
#  28  c_cond_B                    2852 non-null   int32
#  29  c_cond_C                    2852 non-null   int32
#  30  if_automatic_no             2852 non-null   int32
#  31  if_automatic_yes            2852 non-null   int32
# dtypes: int32(32)
# memory usage: 378.8 KB

# %%
#Remove base level for each categorical variable + non-significant dummies
dummy_vars.drop(columns = ['city_Tehran',
                           'city_Mashhad',
                           'fuel_type_gasoline',
                           'fuel_type_hybrid', 
                           'fuel_type_LPG', 
                           'model_405',
                           'color_levels_white', 
                           'e_cond_A',
                           'e_cond_B',
                           'c_cond_A', 
                           'if_automatic_no' 
                           ], inplace = True)

# %%
#Define the feature matrix 
X_ = test[['km', 'insurance_time_to_expire', 'age', 'b_cond']]
X_test = pd.concat([X_, dummy_vars], axis = 1)
X_test = sm.add_constant(X_test) #add constant
X_test.head()
# Out:
#       const      km  insurance_time_to_expire  age  b_cond  city_Isfahan
# 2847    1.0   27000                        10    2       2             0  \
# 8967    1.0  155000                         1    5       1             0
# 1623    1.0  280000                         9   11      13             0
# 2141    1.0   37000                         1    3       1             0
# 8504    1.0   32000                        12    5       1             0
#
#       city_Shiraz  fuel_type_CNG  model_2008  model_206  ...  model_other
# 2847            0              0           0          0  ...            0  \
# 8967            1              0           0          0  ...            0
# 1623            0              1           0          0  ...            0
# 2141            0              0           0          1  ...            0
# 8504            1              0           0          1  ...            0
#
#       color_levels_black  color_levels_graphite gray  color_levels_gray
# 2847                   1                           0                  0  \
# 8967                   0                           0                  0
# 1623                   0                           0                  0
# 2141                   0                           0                  1
# 8504                   0                           0                  0
#
#       color_levels_other  color_levels_silver  e_cond_C  c_cond_B  c_cond_C
# 2847                   0                    0         0         0         0  \
# 8967                   0                    0         0         0         0
# 1623                   0                    1         0         0         0
# 2141                   0                    0         0         0         0
# 8504                   0                    0         0         0         0
#
#       if_automatic_yes
# 2847                 0
# 8967                 1
# 1623                 0
# 2141                 0
# 8504                 0
#
# [5 rows x 26 columns]

# %%
X_train.columns
# Out:
# Index(['const', 'km', 'insurance_time_to_expire', 'age', 'b_cond',
#        'city_Isfahan', 'city_Shiraz', 'fuel_type_CNG', 'model_2008',
#        'model_206', 'model_207i', 'model_407', 'model_PARS', 'model_RD',
#        'model_RDI', 'model_ROA', 'model_other', 'color_levels_black',
#        'color_levels_graphite gray', 'color_levels_gray', 'color_levels_other',
#        'color_levels_silver', 'e_cond_C', 'c_cond_B', 'c_cond_C',
#        'if_automatic_yes'],
#       dtype='object')

# %%
X_test.columns
# Out:
# Index(['const', 'km', 'insurance_time_to_expire', 'age', 'b_cond',
#        'city_Isfahan', 'city_Shiraz', 'fuel_type_CNG', 'model_2008',
#        'model_206', 'model_207i', 'model_407', 'model_PARS', 'model_RD',
#        'model_RDI', 'model_ROA', 'model_other', 'color_levels_black',
#        'color_levels_graphite gray', 'color_levels_gray', 'color_levels_other',
#        'color_levels_silver', 'e_cond_C', 'c_cond_B', 'c_cond_C',
#        'if_automatic_yes'],
#       dtype='object')

# %%
#Prediction using model 4
test_pred = model_4.predict(X_test)
test_pred
# Out:
# 2847    0.726682
# 8967    1.029158
# 1623   -0.833611
# 2141    0.441063
# 8504    0.398347
#           ...
# 6617    0.816353
# 812     0.252565
# 2339    2.034410
# 9269    0.673814
# 5572   -1.529701
# Length: 2852, dtype: float64

# %%
#Inverse transformation of predicted values
test['pred'] = pd.Series(boxcox.inverse_transform(test_pred.values.reshape(-1, 1)).reshape(-1), 
                         index = test_pred.index)
test.head()
# Out:
#         no       time    city                brand  production_year    color
# 2847  2848 2022-04-02  Tehran     PEUGEOT PARS SAL             1399     مشکی  \
# 8967  8968 2022-03-19  Shiraz     PEUGEOT PARS SAL             1396     سفید
# 1623  1624 2022-03-05  Tehran  PEUGEOT 405 GLX CNG             1390  نقره ای
# 2141  2142 2022-03-19  Tehran   PEUGEOT 206 Type 2             1398  خاکستری
# 8504  8505 2022-03-12  Shiraz    PEUGEOT 206 SD V8             1396     سفید
#
#           km       body_condition engine_condition chassis_condition  ...
# 2847   27000         خط و خش جزیی             سالم       سالم و پلمپ  ...  \
# 8967  155000    سالم و بی خط و خش             سالم       سالم و پلمپ  ...
# 1623  280000  رنگ شدگی در ۳ ناحیه             سالم       سالم و پلمپ  ...
# 2141   37000    سالم و بی خط و خش             سالم       سالم و پلمپ  ...
# 8504   32000    سالم و بی خط و خش             سالم       سالم و پلمپ  ...
#
#           price model shamsy_year  age color_levels  b_cond  e_cond c_cond
# 2847  280000000  PARS        1399    2        black       2       A      A  \
# 8967  225000000  PARS        1396    5        white       1       A      A
# 1623  130000000   405        1390   11       silver      13       A      A
# 2141  238000000   206        1398    3         gray       1       A      A
# 8504  266000000   206        1396    5        white       1       A      A
#
#       if_automatic          pred
# 2847            no  2.796486e+08
# 8967           yes  3.164444e+08
# 1623            no  1.263513e+08
# 2141            no  2.470195e+08
# 8504            no  2.423162e+08
#
# [5 rows x 23 columns]

# %%
#Actual vs. Prediction
plt.scatter(x = test['price'], y = test['pred'], c = 'gray', alpha = 0.7)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.title('Actual vs. Prediction')

#Add 45 degree line
xp = np.linspace(test['price'].min(), test['price'].max(), 100)
plt.plot(xp, xp, c = 'red', linewidth = 3, alpha = 0.7)
plt.show()

# %%
#Absolute percentage error
test['abs_pct_err'] = round(abs(test['price'] - test['pred']) / test['price'] * 100, 2)

# %%
#Summary statistics for absolute percentage error
test['abs_pct_err'].describe()
# Out:
# count    2852.000000
# mean        9.375936
# std        22.836628
# min         0.000000
# 25%         3.680000
# 50%         7.390000
# 75%        11.190000
# max      1126.390000
# Name: abs_pct_err, dtype: float64

# %%
#Check obervations with large absolute percentage error
pd.set_option('display.max_columns', 25)
test.sort_values(by = 'abs_pct_err', ascending = False).head(20)
# Out:
#         no       time     city                      brand  production_year
# 8234  8235 2022-03-27   Shiraz         PEUGEOT 405 GL CNG             1390  \
# 5666  5667 2022-03-26  Mashhad         PEUGEOT 405 GL CNG             1388
# 1555  1556 2022-03-05   Tehran           PEUGEOT PARS SAL             1400
# 7348  7349 2022-03-12  Isfahan             PEUGEOT RD GAS             1385
# 4800  4801 2022-03-26   Tehran             PEUGEOT 508 GT             2017
# 8116  8117 2022-03-12  Isfahan     PEUGEOT 405 SLX HYBRID             1390
# 1298  1299 2022-03-26   Tehran         PEUGEOT 405 GL GAS             1372
# 8735  8736 2022-03-26   Shiraz             PEUGEOT RD LPG             1382
# 6774  6775 2022-03-12  Isfahan             PEUGEOT RD LPG             1384
# 7617  7618 2022-03-19  Isfahan         PEUGEOT 405 GL CNG             1390
# 9079  9080 2022-03-29   Shiraz             PEUGEOT RD GAS             1379
# 5557  5558 2022-03-19  Mashhad        PEUGEOT 405 GLX CNG             1372
# 1422  1423 2022-03-12   Tehran                PEUGEOT 301             2016
# 6701  6702 2022-03-26  Isfahan  PEUGEOT 405 STATION WAGON             1388
# 8832  8833 2022-03-26   Shiraz    PEUGEOT 405 GLX TU5 GAS             1388
# 2515  2516 2022-03-26   Tehran                PEUGEOT 301             2016
# 7849  7850 2022-03-30  Isfahan             PEUGEOT RD LPG             1382
# 827    828 2022-03-29   Tehran             PEUGEOT RD LPG             1384
# 714    715 2022-03-29   Tehran             PEUGEOT RD LPG             1385
# 8349  8350 2022-03-26   Shiraz        PEUGEOT 405 GLX CNG             1396
#
#           color      km       body_condition engine_condition
# 8234    نقره ای    1111             تمام رنگ             سالم  \
# 5666        زرد       0         خط و خش جزیی             سالم
# 1555       سفید       0    سالم و بی خط و خش             سالم
# 7348       یشمی  300000             تمام رنگ             سالم
# 4800  سفید صدفی    4000    سالم و بی خط و خش             سالم
# 8116        زرد  150000    سالم و بی خط و خش             سالم
# 1298       قرمز  300000             تمام رنگ             سالم
# 8735       طوسی  111111         خط و خش جزیی             سالم
# 6774       یشمی  220000         خط و خش جزیی             سالم
# 7617        زرد  350000  رنگ شدگی در ۱ ناحیه             سالم
# 9079        سبز       1         خط و خش جزیی             سالم
# 5557     دلفینی  350000             تمام رنگ             سالم
# 1422       سفید   45000    سالم و بی خط و خش             سالم
# 6701        زرد       0         خط و خش جزیی             سالم
# 8832        زرد  400000         خط و خش جزیی             سالم
# 2515       سفید   70000    سالم و بی خط و خش             سالم
# 7849       عدسی   24153         خط و خش جزیی             سالم
# 827        یشمی  100000         خط و خش جزیی             سالم
# 714        یشمی     111         خط و خش جزیی             سالم
# 8349        زرد  150000         خط و خش جزیی             سالم
#
#      chassis_condition  insurance_time_to_expire   gearbox fuel_type
# 8234       سالم و پلمپ                        11   دنده ای       CNG  \
# 5666       سالم و پلمپ                        10   دنده ای       CNG
# 1555       سالم و پلمپ                        12   دنده ای  gasoline
# 7348       سالم و پلمپ                        12  اتوماتیک  gasoline
# 4800       سالم و پلمپ                        11  اتوماتیک  gasoline
# 8116       سالم و پلمپ                        12   دنده ای    hybrid
# 1298       سالم و پلمپ                        12   دنده ای  gasoline
# 8735       سالم و پلمپ                        11   دنده ای       LPG
# 6774       سالم و پلمپ                         7   دنده ای       LPG
# 7617       سالم و پلمپ                        12   دنده ای       CNG
# 9079       سالم و پلمپ                         1   دنده ای  gasoline
# 5557       سالم و پلمپ                         5   دنده ای       CNG
# 1422       سالم و پلمپ                        11  اتوماتیک  gasoline
# 6701       سالم و پلمپ                         2   دنده ای  gasoline
# 8832       سالم و پلمپ                        12   دنده ای  gasoline
# 2515       سالم و پلمپ                        10  اتوماتیک  gasoline
# 7849       سالم و پلمپ                         6   دنده ای       LPG
# 827        سالم و پلمپ                         1   دنده ای       LPG
# 714        سالم و پلمپ                        11   دنده ای       LPG
# 8349       سالم و پلمپ                         2   دنده ای       CNG
#
#            price  model  shamsy_year  age color_levels  b_cond e_cond c_cond
# 8234    11111111    405         1390   11       silver      22      A      A  \
# 5666    58000000    405         1388   13        other       2      A      A
# 1555   138000000   PARS         1400    1        white       1      A      A
# 7348    45000000     RD         1385   16        other      22      A      A
# 4800  1605000000  other         1396    5        other       1      A      A
# 8116    85000000    405         1390   11        other       1      A      A
# 1298   110000000    405         1372   29        other      22      A      A
# 8735    30000000     RD         1382   19        other       2      A      A
# 6774    35000000     RD         1384   17        other       2      A      A
# 7617    77000000    405         1390   11        other      11      A      A
# 9079    25000000     RD         1379   22        other       2      A      A
# 5557    65000000    405         1372   29        other      22      A      A
# 1422   690000000  other         1395    6        white       1      A      A
# 6701    88000000    405         1388   13        other       2      A      A
# 8832    74900000    405         1388   13        other       2      A      A
# 2515   650000000  other         1395    6        white       1      A      A
# 7849    35000000     RD         1382   19        other       2      A      A
# 827     38000000     RD         1384   17        other       2      A      A
# 714     45000000     RD         1385   16        other       2      A      A
# 8349   127000000    405         1396    5        other       2      A      A
#
#      if_automatic          pred  abs_pct_err
# 8234           no  1.362653e+08      1126.39
# 5666           no  1.368293e+08       135.91
# 1555           no  3.016851e+08       118.61
# 7348          yes  8.658825e+07        92.42
# 4800          yes  2.562358e+08        84.04
# 8116           no  1.535551e+08        80.65
# 1298           no  2.666335e+07        75.76
# 8735           no  5.242949e+07        74.76
# 6774           no  5.941151e+07        69.75
# 7617           no  1.306176e+08        69.63
# 9079           no  4.117951e+07        64.72
# 5557           no  2.347088e+07        63.89
# 1422          yes  2.537663e+08        63.22
# 6701           no  1.427751e+08        62.24
# 8832           no  1.213680e+08        62.04
# 2515          yes  2.516250e+08        61.29
# 7849           no  5.609213e+07        60.26
# 827            no  6.010962e+07        58.18
# 714            no  7.062924e+07        56.95
# 8349           no  1.968116e+08        54.97

# %%
#Marketing Requirement
sum(test['abs_pct_err'] <= 15) / test.shape[0] * 100
# Out:
# 87.02664796633941
